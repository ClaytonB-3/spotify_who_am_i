# %%
from spotipy.oauth2 import SpotifyClientCredentials
import spotipy
import requests
import pandas as pd
import ast
from os import listdir
import inspect
import json
import settings

# %% [markdown]
# ## Connect to Spotify API with spotipy
# Set client_id and client_secret for ClientCredential authenication for spotipy and connect to Spotify API through spotipy.

# %%
#client_id and client_secret set in settings.py
client_credentials_manager = SpotifyClientCredentials(client_id = settings.client_id, client_secret = settings.client_secret)
sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager)

# %% [markdown]
# ## Read Spotify json Data into Python
# We'll start by reading the provided json listening history files into python as a list of dictionaries containing the following information: <br>
#
# 1. endTime - The date and time at which listening to the track ended. <br>
# 2. artistName - The name of the artist of the track (only the releasing artist, not features or collaborations). <br>
# 3. trackName - The name of the track. Note that this includes songs and pocast episodes. <br>
# 4. msPlayed.- The number of milliseconds of the track that were played. <br> <br>
#
# We will also export this list of dictionaries as a csv of the full listening history for later anlysis.

# %%
def convert_json(path: str): 
    
    '''This function will return a list of dictionaries. Each dictionary will contain the trackName, 
    trackArtist, end date and time it was listened to, and how many milliseconds of the track were listened to. 
    How it does this is commented inline in the function''';
    
    # Create a list of all file paths in the folder specified in the function parameter that start with the string
    # 'StreamingHistory', which is how Spotify delivers the listening history files. 
    # StreamingHistory0, StreamingHistory1, etc
    files = [path + x for x in listdir(path) if x.split('.')[0][:-1] == 'StreamingHistory']
    # Read each json file into python, confirm it is a python object iwth ast.literal_eval, and add each 
    # dictionary in the file to the end of a list and return the final list of dictionaries.  
    all_streamings = []
    for file in files:
        with open(file, 'r', encoding = 'UTF-8') as f:
            new_streamings = ast.literal_eval(f.read())
            all_streamings += [streaming for streaming in new_streamings]
    return all_streamings

#Run the function on the file path where the listening histories are located (path entered in settings.py)
streaming_list = convert_json(settings.project_folder_path)
#Print the number of total tracks listened to in the year of data provided and display the first 100 items of the list.
streaming_list[:100]
# Out:
# [{'endTime': '2020-05-01 02:01',
#   'artistName': 'SAINt JHN',
#   'trackName': 'Roses - Imanbek Remix',
#   'msPlayed': 176218},
#  {'endTime': '2020-05-01 02:04',
#   'artistName': 'Ehrling',
#   'trackName': 'In My Soul',
#   'msPlayed': 1909},
#  {'endTime': '2020-05-01 02:04',
#   'artistName': 'The Middle Coast',
#   'trackName': 'Me Tonight',
#   'msPlayed': 177426},
#  {'endTime': '2020-05-01 02:07',
#   'artistName': 'Kygo',
#   'trackName': 'Like It Is',
#   'msPlayed': 183067},
#  {'endTime': '2020-05-01 02:10',
#   'artistName': 'Tep No',
#   'trackName': 'Breathe, Be Happy - French Braids Remix',
#   'msPlayed': 171250},
#  {'endTime': '2020-05-01 02:14',
#   'artistName': 'Alesso',
#   'trackName': 'One Last Time',
#   'msPlayed': 240383},
#  {'endTime': '2020-05-01 02:16',
#   'artistName': 'MEDUZA',
#   'trackName': 'Born To Love (feat. SHELLS)',
#   'msPlayed': 162295},
#  {'endTime': '2020-05-01 02:20',
#   'artistName': 'Field Report',
#   'trackName': 'Home (Leave the Lights On)',
#   'msPlayed': 221146},
#  {'endTime': '2020-05-01 02:24',
#   'artistName': 'Ripe',
#   'trackName': 'Little Less Polite',
#   'msPlayed': 262408},
#  {'endTime': '2020-05-01 02:28',
#   'artistName': 'JONES',
#   'trackName': 'Hoops - Acoustic',
#   'msPlayed': 206062},
#  {'endTime': '2020-05-01 02:28',
#   'artistName': 'The Rubens',
#   'trackName': 'Hoops',
#   'msPlayed': 31133},
#  {'endTime': '2020-05-01 02:31',
#   'artistName': 'SAINt JHN',
#   'trackName': 'Roses - Imanbek Remix',
#   'msPlayed': 176218},
#  {'endTime': '2020-05-01 02:34',
#   'artistName': 'Medasin',
#   'trackName': 'Everytime',
#   'msPlayed': 170884},
#  {'endTime': '2020-05-01 02:38',
#   'artistName': 'Louis The Child',
#   'trackName': 'Love Is Alive (feat. Elohim) - Chet Porter Remix',
#   'msPlayed': 200969},
#  {'endTime': '2020-05-01 02:41',
#   'artistName': 'BUNT.',
#   'trackName': "Sure Don't Miss You (feat. The Dip)",
#   'msPlayed': 202992},
#  {'endTime': '2020-05-01 02:45',
#   'artistName': 'Ripe',
#   'trackName': 'Backup',
#   'msPlayed': 224573},
#  {'endTime': '2020-05-01 02:48',
#   'artistName': 'Diplo',
#   'trackName': 'Heartless (with Julia Michaels & Morgan Wallen)',
#   'msPlayed': 172973},
#  {'endTime': '2020-05-01 02:51',
#   'artistName': 'FISHER',
#   'trackName': 'Freaks',
#   'msPlayed': 175255},
#  {'endTime': '2020-05-01 02:54',
#   'artistName': 'ODESZA',
#   'trackName': 'Line Of Sight - Chet Porter Remix',
#   'msPlayed': 232249},
#  {'endTime': '2020-05-01 02:59',
#   'artistName': 'Lauv',
#   'trackName': 'Modern Loneliness',
#   'msPlayed': 252337},
#  {'endTime': '2020-05-01 04:10',
#   'artistName': 'Flume',
#   'trackName': 'The Difference',
#   'msPlayed': 8777},
#  {'endTime': '2020-05-01 14:11',
#   'artistName': 'BRONSON',
#   'trackName': 'HEART ATTACK (feat. lau.ra)',
#   'msPlayed': 209600},
#  {'endTime': '2020-05-01 14:14',
#   'artistName': 'Lemaitre',
#   'trackName': 'Joe',
#   'msPlayed': 197122},
#  {'endTime': '2020-05-01 14:18',
#   'artistName': 'Golden Features',
#   'trackName': 'Paradise',
#   'msPlayed': 215253},
#  {'endTime': '2020-05-01 14:22',
#   'artistName': 'ODESZA',
#   'trackName': 'Memories That You Call (feat. Monsoonsiren) - ODESZA & Golden Features VIP Remix',
#   'msPlayed': 219506},
#  {'endTime': '2020-05-01 14:26',
#   'artistName': 'BRONSON',
#   'trackName': 'VAULTS',
#   'msPlayed': 244453},
#  {'endTime': '2020-05-01 14:29',
#   'artistName': 'Milky Chance',
#   'trackName': "Don't Let Me Down",
#   'msPlayed': 200391},
#  {'endTime': '2020-05-01 14:32',
#   'artistName': 'Quinn XCII',
#   'trackName': 'Coffee',
#   'msPlayed': 180053},
#  {'endTime': '2020-05-01 14:35',
#   'artistName': 'Steve Brian',
#   'trackName': 'Astral Haven - Paul Arcane Remix',
#   'msPlayed': 160492},
#  {'endTime': '2020-05-01 18:00',
#   'artistName': 'Gryffin',
#   'trackName': 'Need Your Love (feat. Noah Kahan) - Nurko Remix',
#   'msPlayed': 106607},
#  {'endTime': '2020-05-01 18:00',
#   'artistName': 'BRONSON',
#   'trackName': 'HEART ATTACK (feat. lau.ra)',
#   'msPlayed': 10432},
#  {'endTime': '2020-05-01 18:04',
#   'artistName': 'BRONSON',
#   'trackName': 'HEART ATTACK (feat. lau.ra)',
#   'msPlayed': 209600},
#  {'endTime': '2020-05-01 18:08',
#   'artistName': 'BRONSON',
#   'trackName': 'VAULTS',
#   'msPlayed': 244453},
#  {'endTime': '2020-05-01 18:11',
#   'artistName': 'BRONSON',
#   'trackName': 'HEART ATTACK (feat. lau.ra)',
#   'msPlayed': 209600},
#  {'endTime': '2020-05-01 18:15',
#   'artistName': 'BRONSON',
#   'trackName': 'VAULTS',
#   'msPlayed': 244453},
#  {'endTime': '2020-05-01 18:19',
#   'artistName': 'BRONSON',
#   'trackName': 'HEART ATTACK (feat. lau.ra)',
#   'msPlayed': 209600},
#  {'endTime': '2020-05-01 18:23',
#   'artistName': 'BRONSON',
#   'trackName': 'VAULTS',
#   'msPlayed': 244453},
#  {'endTime': '2020-05-01 18:26',
#   'artistName': 'BRONSON',
#   'trackName': 'HEART ATTACK (feat. lau.ra)',
#   'msPlayed': 209600},
#  {'endTime': '2020-05-01 18:31',
#   'artistName': 'BRONSON',
#   'trackName': 'VAULTS',
#   'msPlayed': 244453},
#  {'endTime': '2020-05-01 18:34',
#   'artistName': 'BRONSON',
#   'trackName': 'HEART ATTACK (feat. lau.ra)',
#   'msPlayed': 209600},
#  {'endTime': '2020-05-01 18:38',
#   'artistName': 'BRONSON',
#   'trackName': 'VAULTS',
#   'msPlayed': 244453},
#  {'endTime': '2020-05-01 18:42',
#   'artistName': 'BRONSON',
#   'trackName': 'HEART ATTACK (feat. lau.ra)',
#   'msPlayed': 209600},
#  {'endTime': '2020-05-01 18:46',
#   'artistName': 'BRONSON',
#   'trackName': 'VAULTS',
#   'msPlayed': 244453},
#  {'endTime': '2020-05-01 18:49',
#   'artistName': 'BRONSON',
#   'trackName': 'HEART ATTACK (feat. lau.ra)',
#   'msPlayed': 209600},
#  {'endTime': '2020-05-01 18:53',
#   'artistName': 'BRONSON',
#   'trackName': 'VAULTS',
#   'msPlayed': 244453},
#  {'endTime': '2020-05-01 18:57',
#   'artistName': 'BRONSON',
#   'trackName': 'HEART ATTACK (feat. lau.ra)',
#   'msPlayed': 209600},
#  {'endTime': '2020-05-01 19:01',
#   'artistName': 'BRONSON',
#   'trackName': 'VAULTS',
#   'msPlayed': 244453},
#  {'endTime': '2020-05-01 19:03',
#   'artistName': 'BRONSON',
#   'trackName': 'HEART ATTACK (feat. lau.ra)',
#   'msPlayed': 135136},
#  {'endTime': '2020-05-01 20:33',
#   'artistName': 'BRONSON',
#   'trackName': 'HEART ATTACK (feat. lau.ra)',
#   'msPlayed': 74462},
#  {'endTime': '2020-05-01 20:37',
#   'artistName': 'BRONSON',
#   'trackName': 'VAULTS',
#   'msPlayed': 244453},
#  {'endTime': '2020-05-01 20:41',
#   'artistName': 'BRONSON',
#   'trackName': 'HEART ATTACK (feat. lau.ra)',
#   'msPlayed': 209600},
#  {'endTime': '2020-05-01 20:45',
#   'artistName': 'BRONSON',
#   'trackName': 'VAULTS',
#   'msPlayed': 244453},
#  {'endTime': '2020-05-01 20:48',
#   'artistName': 'BRONSON',
#   'trackName': 'HEART ATTACK (feat. lau.ra)',
#   'msPlayed': 209600},
#  {'endTime': '2020-05-01 20:52',
#   'artistName': 'BRONSON',
#   'trackName': 'VAULTS',
#   'msPlayed': 244453},
#  {'endTime': '2020-05-01 20:56',
#   'artistName': 'BRONSON',
#   'trackName': 'HEART ATTACK (feat. lau.ra)',
#   'msPlayed': 209600},
#  {'endTime': '2020-05-01 21:00',
#   'artistName': 'BRONSON',
#   'trackName': 'VAULTS',
#   'msPlayed': 244453},
#  {'endTime': '2020-05-01 21:03',
#   'artistName': 'BRONSON',
#   'trackName': 'HEART ATTACK (feat. lau.ra)',
#   'msPlayed': 209600},
#  {'endTime': '2020-05-01 21:07',
#   'artistName': 'BRONSON',
#   'trackName': 'VAULTS',
#   'msPlayed': 244453},
#  {'endTime': '2020-05-01 21:11',
#   'artistName': 'BRONSON',
#   'trackName': 'HEART ATTACK (feat. lau.ra)',
#   'msPlayed': 209600},
#  {'endTime': '2020-05-01 21:15',
#   'artistName': 'BRONSON',
#   'trackName': 'VAULTS',
#   'msPlayed': 244453},
#  {'endTime': '2020-05-01 21:18',
#   'artistName': 'BRONSON',
#   'trackName': 'HEART ATTACK (feat. lau.ra)',
#   'msPlayed': 209600},
#  {'endTime': '2020-05-01 21:22',
#   'artistName': 'BRONSON',
#   'trackName': 'VAULTS',
#   'msPlayed': 244453},
#  {'endTime': '2020-05-01 21:26',
#   'artistName': 'BRONSON',
#   'trackName': 'HEART ATTACK (feat. lau.ra)',
#   'msPlayed': 209600},
#  {'endTime': '2020-05-01 21:30',
#   'artistName': 'BRONSON',
#   'trackName': 'VAULTS',
#   'msPlayed': 244453},
#  {'endTime': '2020-05-01 21:34',
#   'artistName': 'BRONSON',
#   'trackName': 'HEART ATTACK (feat. lau.ra)',
#   'msPlayed': 209600},
#  {'endTime': '2020-05-01 21:38',
#   'artistName': 'BRONSON',
#   'trackName': 'VAULTS',
#   'msPlayed': 244453},
#  {'endTime': '2020-05-01 21:41',
#   'artistName': 'BRONSON',
#   'trackName': 'HEART ATTACK (feat. lau.ra)',
#   'msPlayed': 209600},
#  {'endTime': '2020-05-01 22:36',
#   'artistName': 'BRONSON',
#   'trackName': 'VAULTS',
#   'msPlayed': 77064},
#  {'endTime': '2020-05-02 17:44',
#   'artistName': 'Louis The Child',
#   'trackName': 'Every Color (with Foster The People)',
#   'msPlayed': 2484},
#  {'endTime': '2020-05-02 17:44',
#   'artistName': 'BRONSON',
#   'trackName': 'HEART ATTACK (feat. lau.ra)',
#   'msPlayed': 7105},
#  {'endTime': '2020-05-02 17:47',
#   'artistName': 'Milky Chance',
#   'trackName': "Don't Let Me Down",
#   'msPlayed': 200391},
#  {'endTime': '2020-05-02 17:51',
#   'artistName': 'Lemaitre',
#   'trackName': 'Joe',
#   'msPlayed': 197122},
#  {'endTime': '2020-05-02 17:54',
#   'artistName': 'FISHER',
#   'trackName': 'Freaks',
#   'msPlayed': 175255},
#  {'endTime': '2020-05-02 17:57',
#   'artistName': 'Ripe',
#   'trackName': 'Backup',
#   'msPlayed': 224573},
#  {'endTime': '2020-05-02 18:00',
#   'artistName': 'SAINt JHN',
#   'trackName': 'Roses - Imanbek Remix',
#   'msPlayed': 176218},
#  {'endTime': '2020-05-02 18:01',
#   'artistName': 'The Middle Coast',
#   'trackName': 'Me Tonight',
#   'msPlayed': 43527},
#  {'endTime': '2020-05-03 17:59',
#   'artistName': 'Amber Mark',
#   'trackName': '1894',
#   'msPlayed': 179183},
#  {'endTime': '2020-05-03 17:59',
#   'artistName': 'Kehlani',
#   'trackName': 'F&MU',
#   'msPlayed': 636},
#  {'endTime': '2020-05-03 18:02',
#   'artistName': 'Imanbek',
#   'trackName': "I'm Just Feelin' (Du Du Du)",
#   'msPlayed': 164884},
#  {'endTime': '2020-05-03 18:06',
#   'artistName': 'Shallou',
#   'trackName': 'Older - Felix Cartal Remix',
#   'msPlayed': 233769},
#  {'endTime': '2020-05-03 18:09',
#   'artistName': 'Steve Aoki',
#   'trackName': 'I Love My Friends - Armin van Buuren & Avian Grays Remix',
#   'msPlayed': 179121},
#  {'endTime': '2020-05-03 18:13',
#   'artistName': 'BRONSON',
#   'trackName': 'HEART ATTACK (feat. lau.ra)',
#   'msPlayed': 209600},
#  {'endTime': '2020-05-03 18:15',
#   'artistName': 'Fubu',
#   'trackName': 'Freak Like Me (feat. Kate Wild)',
#   'msPlayed': 156795},
#  {'endTime': '2020-05-03 20:01',
#   'artistName': 'Fatum',
#   'trackName': 'We’re All In This Together (Push The Button) [ABGT378] - Above & Beyond Respray',
#   'msPlayed': 121766},
#  {'endTime': '2020-05-03 20:55',
#   'artistName': 'The Middle Coast',
#   'trackName': 'Me Tonight',
#   'msPlayed': 133859},
#  {'endTime': '2020-05-03 20:58',
#   'artistName': 'Ehrling',
#   'trackName': 'In My Soul',
#   'msPlayed': 195483},
#  {'endTime': '2020-05-03 21:00',
#   'artistName': 'Kygo',
#   'trackName': 'Like It Is',
#   'msPlayed': 142595},
#  {'endTime': '2020-05-03 21:05',
#   'artistName': 'Melt',
#   'trackName': 'Sour Candy',
#   'msPlayed': 295706},
#  {'endTime': '2020-05-03 21:06',
#   'artistName': 'Kygo',
#   'trackName': 'It Ain’t Me (with Selena Gomez)',
#   'msPlayed': 77510},
#  {'endTime': '2020-05-04 00:34',
#   'artistName': 'SAINt JHN',
#   'trackName': 'Roses - Imanbek Remix',
#   'msPlayed': 176218},
#  {'endTime': '2020-05-04 00:35',
#   'artistName': 'Flume',
#   'trackName': 'Rushing Back',
#   'msPlayed': 22854},
#  {'endTime': '2020-05-04 00:39',
#   'artistName': 'Ripe',
#   'trackName': 'Backup',
#   'msPlayed': 224573},
#  {'endTime': '2020-05-04 03:54',
#   'artistName': 'Milky Chance',
#   'trackName': "Don't Let Me Down",
#   'msPlayed': 103417},
#  {'endTime': '2020-05-04 15:33',
#   'artistName': 'LOYAL',
#   'trackName': 'Light up for You - Acoustic',
#   'msPlayed': 226539},
#  {'endTime': '2020-05-04 15:37',
#   'artistName': 'No Spirit',
#   'trackName': 'Better Now',
#   'msPlayed': 206303},
#  {'endTime': '2020-05-04 15:41',
#   'artistName': 'Chace',
#   'trackName': 'Us',
#   'msPlayed': 296869},
#  {'endTime': '2020-05-04 15:45',
#   'artistName': 'Shuhandz',
#   'trackName': 'Tell Me',
#   'msPlayed': 193846},
#  {'endTime': '2020-05-04 15:48',
#   'artistName': 'SŸDE',
#   'trackName': 'Her Touch',
#   'msPlayed': 185243},
#  {'endTime': '2020-05-04 15:52',
#   'artistName': 'DLG.',
#   'trackName': 'Inside of My Eyelids',
#   'msPlayed': 228891},
#  {'endTime': '2020-05-05 00:39',
#   'artistName': 'Madism',
#   'trackName': 'If The World Was Ending (feat. Julia Michaels) - Madism Remix',
#   'msPlayed': 109721}]

# %%
#convert list of dictionaries to a dataframe and then save as a csv
df_history = pd.DataFrame(streaming_list)
df_history.to_csv('full_streaming_history.csv')

# %% [markdown]
# ## Create Dictionary of TrackName: ArtistName Pairs for Unique Tracks
# We will be querying the Spotify API for additional track information using the track name and artist name, so we will create a dictionary of all the unique tracks in our listening history to search over. We then check the length of this new dictionary and see that there are 3432 unique tracks in my listening history over the last year.

# %%
#For each dictionary in the full list of dictionaries of tracks, check if the trackName is already in a new dictionary
#If it is not, add it with a value pair of the artistName. 
track_artist_dict = {} #unique track artist pairs
for item in streaming_list:
    if item['trackName'] not in track_artist_dict:
        track_artist_dict[item['trackName']] = item['artistName']
        
print(len(track_artist_dict))
track_artist_dict
# Out:
# 3432
# {'Roses - Imanbek Remix': 'SAINt JHN',
#  'In My Soul': 'Ehrling',
#  'Me Tonight': 'The Middle Coast',
#  'Like It Is': 'Kygo',
#  'Breathe, Be Happy - French Braids Remix': 'Tep No',
#  'One Last Time': 'Alesso',
#  'Born To Love (feat. SHELLS)': 'MEDUZA',
#  'Home (Leave the Lights On)': 'Field Report',
#  'Little Less Polite': 'Ripe',
#  'Hoops - Acoustic': 'JONES',
#  'Hoops': 'The Rubens',
#  'Everytime': 'Medasin',
#  'Love Is Alive (feat. Elohim) - Chet Porter Remix': 'Louis The Child',
#  "Sure Don't Miss You (feat. The Dip)": 'BUNT.',
#  'Backup': 'Ripe',
#  'Heartless (with Julia Michaels & Morgan Wallen)': 'Diplo',
#  'Freaks': 'FISHER',
#  'Line Of Sight - Chet Porter Remix': 'ODESZA',
#  'Modern Loneliness': 'Lauv',
#  'The Difference': 'Flume',
#  'HEART ATTACK (feat. lau.ra)': 'BRONSON',
#  'Joe': 'Lemaitre',
#  'Paradise': 'Golden Features',
#  'Memories That You Call (feat. Monsoonsiren) - ODESZA & Golden Features VIP Remix': 'ODESZA',
#  'VAULTS': 'BRONSON',
#  "Don't Let Me Down": 'Milky Chance',
#  'Coffee': 'Quinn XCII',
#  'Astral Haven - Paul Arcane Remix': 'Steve Brian',
#  'Need Your Love (feat. Noah Kahan) - Nurko Remix': 'Gryffin',
#  'Every Color (with Foster The People)': 'Louis The Child',
#  '1894': 'Amber Mark',
#  'F&MU': 'Kehlani',
#  "I'm Just Feelin' (Du Du Du)": 'Imanbek',
#  'Older - Felix Cartal Remix': 'Shallou',
#  'I Love My Friends - Armin van Buuren & Avian Grays Remix': 'Steve Aoki',
#  'Freak Like Me (feat. Kate Wild)': 'Fubu',
#  'We’re All In This Together (Push The Button) [ABGT378] - Above & Beyond Respray': 'Fatum',
#  'Sour Candy': 'Melt',
#  'It Ain’t Me (with Selena Gomez)': 'Kygo',
#  'Rushing Back': 'Flume',
#  'Light up for You - Acoustic': 'LOYAL',
#  'Better Now': 'No Spirit',
#  'Us': 'Chace',
#  'Tell Me': 'Shuhandz',
#  'Her Touch': 'SŸDE',
#  'Inside of My Eyelids': 'DLG.',
#  'If The World Was Ending (feat. Julia Michaels) - Madism Remix': 'Madism',
#  'If the World Was Ending - feat. Julia Michaels': 'JP Saxe',
#  'Tadow': 'Masego',
#  'FISA Follies & Trump’s Taxes (with Steve Vladeck)': 'Stay Tuned with Preet',
#  'Silk...': 'Masego',
#  'I Had A Vision': 'Masego',
#  'Lavish Lullaby': 'Masego',
#  'Old Age': 'Masego',
#  'Prone': 'Masego',
#  'Sugar Walls': 'Masego',
#  'Queen Tings': 'Masego',
#  'Just A Little': 'Masego',
#  "Shawty Fishin' (Blame The Net)": 'Masego',
#  'The Scaredy Cats Horror Show': 'Reply All',
#  'Veg Out (Wasting Thyme)': 'Masego',
#  'Need It': 'KAYTRANADA',
#  'Flight 99': 'Masego',
#  'Under The Wind': 'The Tides',
#  'Safe And Sound': 'Burgundy Skies',
#  'alpha waves': 'Eucalyptic',
#  'Mil Sonidos': 'Reina del Mar',
#  'Heavenly Father (feat. Noah Kahan) - Recorded at Electric Lady Studios, NYC': 'Gryffin',
#  'Love Like That': 'Lauv',
#  'Make It Right - Trinix Remix': 'Armin van Buuren',
#  'Make It Right': 'Armin van Buuren',
#  'Right Time': 'Hayden James',
#  'Rebellious': 'Adventure Club',
#  'Beyond the Senses - Bliss Remix': 'Astrix',
#  'Call Me, I Still Love You - Extended Version': 'Two Feet',
#  'Amanecer': 'Deorro',
#  "I Don't Know Why": 'NOTD',
#  'Dreamland': 'Glass Animals',
#  'Draft Recap ': 'Fantasy Focus Football',
#  'Proud (feat. Daecolm) [Dogma Remix]': 'Tchami',
#  'The Baddest': 'GRiZ',
#  'Come Away': 'Sad Money',
#  'In Your Arms (with X Ambassadors) [Alan Walker Remix]': 'ILLENIUM',
#  'Let It Go (feat. Anna Clendening)': 'Matoma',
#  'Sway': 'Shwayze',
#  'Together': 'Manse',
#  'Bloom - Bonus Track': 'The Paper Kites',
#  'Minimum': 'Charlie Cunningham',
#  'Flaws': 'Chloe Foy',
#  'The Night We Met (feat. Phoebe Bridgers)': 'Lord Huron',
#  'Conversation': 'Lucy Rose',
#  'Fallingwater': 'Maggie Rogers',
#  'Alaska - Acoustic': 'Maggie Rogers',
#  'Godmanchester Chinese Bridge - Radio Edit': 'The Howl & The Hum',
#  'Feels Like This': 'Maisie Peters',
#  'Half the World Away': 'AURORA',
#  'Decatur, or, Round of Applause for Your Step-Mother!': 'Sufjan Stevens',
#  'The Funeral': 'Band of Horses',
#  'Brownstone Alley': 'Freddy & Francine',
#  'Dangerous - Cleopold Remix': 'Nick Murphy',
#  'Windows': 'Leo The Kind',
#  'Need You': 'Kidswaste',
#  'Trails': 'Meridian',
#  'All I Want': 'Just Because',
#  'Know Love - OTR Remix': 'RKCB',
#  'All Love': 'ZenAware',
#  "Don't Let Them - Flyboy Remix": 'Young Bombs',
#  'higher': 'pluko',
#  'Jetlag Love': 'Fully Bold',
#  'Needs': 'Nolai',
#  'The Feeling Is All Gone': 'Chase McBride',
#  'Morning': 'LiQWYD',
#  'High (Remix)': 'fika',
#  'we try': 'Teischa',
#  "And Then We'll Be Alright": 'DWLLRS',
#  'Call It Off': 'Skinnydip',
#  'Busy': 'Timothy Infinite',
#  'Painter': 'Opia',
#  'Take Me': 'Race Banyon',
#  'Not December': 'Daniel Loumpouridis',
#  'Friends': 'Night Tales',
#  'Skeletons': 'Saint Sinner',
#  '6 ft.': 'Vindata',
#  'Tender': 'HÖNS',
#  'Tucson': 'Healy',
#  'Before the New': 'Cozmoe',
#  'When It Rains': 'Mr. Popular',
#  'No Return': 'Massane',
#  'Kintsugi': 'Good Lee',
#  'Survivors - Acoustic': 'Passenger',
#  'Reckless': 'Healy',
#  'Nikes On': 'Healy',
#  'Dawning': 'Light of Sun',
#  'What You Love You Must Love Now': 'The Six Parts Seven',
#  'Five in the Morning': 'Ripe',
#  'Curiosity': 'Beau Projet',
#  'Coda': 'Jakob Ahlbom',
#  'When They Come': 'Threading Hair',
#  'Just Look at You': '369',
#  'Event Horizon': 'Airwaves',
#  'Laugavegur': 'Dreyma',
#  'Monumental': 'Antuigo',
#  'Den inre skogen': 'Thomas Jackson',
#  'The Discovery': 'Sulfur Springs',
#  'Target': 'Tom Kalani',
#  'Awaken': 'William Duhamel',
#  'Bouquet with Lilies': 'La Acacia',
#  'Eidolon': 'Monocle Twins',
#  'Escaping Time': 'Benjamin Martins',
#  'Collapse Into Light': 'Evin Iris',
#  'The Disappearance of the Unmoved Mover': 'So Vea',
#  'Ingénue': 'Eline Moss',
#  'Adrift': 'Cooper Sams',
#  'Limitless': 'Lucas Delphy',
#  'Another Mellow Morning': 'Spirits Of Our Dreams',
#  'Pour Up': 'OMAS',
#  'Radiant': 'OMAS',
#  'Drown (feat. Clinton Kane)': 'Martin Garrix',
#  "I'll Wait": 'Kygo',
#  'You Are the One': 'John Mark Nelson',
#  'Bulletproof': 'FARR',
#  'Biggest Dynasty Differences, Rankings & Trade Values - Fantasy Football Podcast': 'Fantasy Footballers - Fantasy Football Podcast',
#  'Touch': 'Dillon Francis',
#  'Friends - Party Pupils Remix': 'Big Gigantic',
#  'go with u - Louis La Roche Remix': 'BAYNK',
#  'Hold Me Close': 'Kasablanca',
#  'You And I - SAINT WKND Remix': 'LÉON',
#  'Coastline (feat. Hollow Coves)': 'Holmsey',
#  "I Can't Help (with Sarcastic Sounds)": 'Shoffy',
#  'Drew Barrymore': 'Bryce Vine',
#  "I Fly (feat. Faouzia) - From 'SCOOB!' The Album": 'Galantis',
#  'Higher Ground (feat. John Martin)': 'Martin Garrix',
#  'ONLY': 'ZHU',
#  'End Of Days': 'Gareth Emery',
#  'Lose Somebody': 'Kygo',
#  'Own It (feat. Ed Sheeran & Burna Boy) - Joel Corry Remix': 'Stormzy',
#  'Own It (feat. Ed Sheeran & Burna Boy)': 'Stormzy',
#  'Blinded By Your Grace, Pt. 2 (feat. MNEK)': 'Stormzy',
#  'This Time (Never Be Alone Again)': 'Dada Life',
#  'At Midnight': 'Borgeous',
#  'Homecoming - Spoken Word with Elena Brower': 'Above & Beyond',
#  'Lose You': 'Tiësto',
#  'Living, Breathing': 'ford.',
#  'LA Money': 'ALMA',
#  'Under The Same Sky': 'City of the Sun',
#  'House Arrest': 'Sofi Tukker',
#  'Zen (with K.Flay & grandson)': 'X Ambassadors',
#  'staring at the sea without you next to me': 'San Holo',
#  'Shivers - Marsh Remix': 'Armin van Buuren',
#  'Juanita - Mark Broom Remix': 'Moon Boots',
#  'enemy': 'Charli XCX',
#  'Hold You Tonight (feat. Chris Lane) - Owen Norton Remix': 'Gryffin',
#  'Garden of Madness 2020 Megamix': 'Dimitri Vegas & Like Mike',
#  'I Still Remember (R3HAB Remix)': 'Caroline Romano',
#  'Gasoline (feat. Laura White)': 'Cash Cash',
#  'Good Things Fall Apart (with Jon Bellion) [SLANDER Remix]': 'ILLENIUM',
#  'Ghosts (feat. Hana) [Honey & Badger Remix]': 'Tchami',
#  'Time - Alan Walker Remix': 'Alan Walker',
#  'Carry On - Möwe Remix': 'Martin Jensen',
#  'Details (feat. Boy Matthews) - Joel Corry Remix': 'Oliver Heldens',
#  'Honolulu - Ninjaneers Remix': 'Slumberville',
#  'Grace': 'Lewis Capaldi',
#  'Bruises': 'Lewis Capaldi',
#  'Hold Me While You Wait': 'Lewis Capaldi',
#  'Someone You Loved': 'Lewis Capaldi',
#  'Maybe': 'Lewis Capaldi',
#  'Forever': 'Lewis Capaldi',
#  'One': 'Lewis Capaldi',
#  "Don't Get Me Wrong": 'Lewis Capaldi',
#  'Hollywood': 'Lewis Capaldi',
#  'Lost On You': 'Lewis Capaldi',
#  'Fade': 'Lewis Capaldi',
#  'Headspace': 'Lewis Capaldi',
#  'Before You Go': 'Lewis Capaldi',
#  'Leaving My Love Behind': 'Lewis Capaldi',
#  'Let It Roll': 'Lewis Capaldi',
#  'Wind of Change, coming May 11': 'Wind of Change ',
#  '1. My Friend Michael': 'Wind of Change ',
#  '2. You Call It An Operation, We Call It A Performance': 'Wind of Change ',
#  '3. America’s Secret Weapon': 'Wind of Change ',
#  '4. The KGB Rock Club': 'Wind of Change ',
#  '5. I Follow The Moskva': 'Wind of Change ',
#  '6. The Doctor Is In': 'Wind of Change ',
#  '7. Rorschach': 'Wind of Change ',
#  '8. Hello, Klaus': 'Wind of Change ',
#  'Ventura': 'City of the Sun',
#  'Someday': 'City of the Sun',
#  'State Lines': 'Novo Amor',
#  'California': 'Little Georgia',
#  'In the End': 'Ricky Green',
#  'Casimir Pulaski Day': 'Sufjan Stevens',
#  'Honey Hold Me': 'Morningsiders',
#  'What Could Have Been': 'Jordan Mackampa',
#  'Quiver (feat. Lonas)': 'Super Duper',
#  'Sleepwalking': 'Super Duper',
#  'Do It For Myself': 'Super Duper',
#  'Be Right There': 'Super Duper',
#  'Spiritual (feat. Mr Gabriel)': 'Super Duper',
#  'All On You': 'Super Duper',
#  'Le magicien des baguettes (The Baguette Magician)': 'Duolingo French Podcast',
#  'Nobody Like You (with Vera Blue)': 'Louis The Child',
#  'The Truth': 'Kygo',
#  'Vacuum': 'Elohim',
#  '3,000 Miles From Home.': 'Ben Zaidi',
#  'Eyes Wide Open': 'Lemaitre',
#  'Modern Loneliness - Ritviz Remix': 'Lauv',
#  'Blue Fear - Eelke Kleijn Day Mix': 'Armin van Buuren',
#  'Jonathan Taylor truth serum': 'RotoUnderworld Radio - Fantasy Football Show',
#  "N'Keal Harry calling the bottom": 'RotoUnderworld Radio - Fantasy Football Show',
#  'Heavy On My Heart': 'Tep No',
#  'Perfect Instance': 'City of the Sun',
#  'Everything': 'City of the Sun',
#  'Rain On Me (with Ariana Grande)': 'Lady Gaga',
#  'Zack Moss Crying Jordan': 'RotoUnderworld Radio - Fantasy Football Show',
#  'The Dreamer': 'Charles Bolt',
#  'Old Rain on a New Day': 'Cora Zea',
#  'Adjustments': 'Josie Mehlin',
#  'Shifts Of Light': 'Avery Young',
#  'Vague': 'Amaranth Cove',
#  'De Fléche': 'Les Manger Tous',
#  'Atlavík': 'Hugar',
#  'Waiting like the Storm': 'Rand Aldo',
#  'Path to Serenity': 'Arya Shae',
#  'Focus': 'IFEELU',
#  'Glaciers': 'Lights & Motion',
#  'Infinite Sustain': 'Amaranth Cove',
#  'Understudy': 'Josie Mehlin',
#  'Closer': '12dust',
#  'Wild Trails': 'Epi-Soothe',
#  "I Don't Trust That Bird of Prey": 'Random Forest',
#  'Selfless': 'Toledo Rains',
#  'Solitude': 'Isobel Belano',
#  'Day 5: For Carol': 'Tom Misch',
#  'Melvin Gordon looking glass': 'RotoUnderworld Radio - Fantasy Football Show',
#  'Sour Patch Kids': 'Bryce Vine',
#  'Fresh Ground (feat. Tim Hecking)': 'Jordan Prince',
#  'Work This Time': 'King Gizzard & The Lizard Wizard',
#  'Sense': 'King Gizzard & The Lizard Wizard',
#  'Slow Jam 1': 'King Gizzard & The Lizard Wizard',
#  'Hot Wax': 'King Gizzard & The Lizard Wizard',
#  'Fishing For Fishies': 'King Gizzard & The Lizard Wizard',
#  "I'm In Your Mind": 'King Gizzard & The Lizard Wizard',
#  'Mars For The Rich': 'King Gizzard & The Lizard Wizard',
#  'Robot Stop': 'King Gizzard & The Lizard Wizard',
#  'Big Fig Wasp': 'King Gizzard & The Lizard Wizard',
#  'Gamma Knife': 'King Gizzard & The Lizard Wizard',
#  'My Round': 'Myles Travitz',
#  'Pity Party - Myles Travitz Remix': 'Melanie Martinez',
#  '144. 2020 NFL Rookie RB Fantasy Impact & Upside ft. Graham Barfield | Fantasy Football Podcast': 'Fantasy Fullback Dive | Fantasy Football Podcast',
#  '#161 Brian vs. Brian': 'Reply All',
#  'Feels Like Forever': 'Kygo',
#  'Freedom': 'Kygo',
#  'Beautiful': 'Kygo',
#  'To Die For': 'Kygo',
#  'Broken Glass': 'Kygo',
#  'How Would I Know': 'Kygo',
#  'Could You Love Me': 'Kygo',
#  'Higher Love': 'Kygo',
#  "Don't Give Up on Love": 'Kygo',
#  'Say You Will': 'Kygo',
#  'Follow': 'Kygo',
#  'Trade Vetoes Suck + The Diontae Johnson Hype Continues': 'PFF Fantasy Football Podcast with Ian Hartitz',
#  'How to Attack Your Dynasty Rookie Draft': 'PFF Fantasy Football Podcast with Ian Hartitz',
#  'Only A Fool (with Pink Sweat$)': 'Galantis',
#  'Free (with Drew Love) - Party Favor Remix': 'Louis The Child',
#  'Nothing Really Matters - Nic Fanciulli Remix': 'Tiësto',
#  'Buenos Aires': 'Tchami',
#  'Sour Candy (with BLACKPINK)': 'Lady Gaga',
#  'Dance with Me (feat. Thomas Rhett & Young Thug)': 'Diplo',
#  'Resistance': 'Black Tiger Sex Machine',
#  'The Bender - Party Pupils Remix': 'Matoma',
#  'Hometown (feat. Zac Brown & Danielle Bradbery)': 'Diplo',
#  'Heartbreak (feat. Ben Burgess)': 'Diplo',
#  'All On Me - Acoustic Version': 'Armin van Buuren',
#  'Rising Stars': 'Fantasy Focus Football',
#  'Intro (feat. Orville Peck)': 'Diplo',
#  'So Long (feat. Cam)': 'Diplo',
#  'Heartless (feat. Morgan Wallen)': 'Diplo',
#  'Lonely (with Jonas Brothers)': 'Diplo',
#  'Do Si Do (feat. Blanco Brown)': 'Diplo',
#  'On Mine (feat. Noah Cyrus)': 'Diplo',
#  'Real Life Stuff (feat. Julia Michaels & Clever)': 'Diplo',
#  'Old Town Road (Diplo Remix)': 'Lil Nas X',
#  'JustYourSoul - Tchami Remix': 'Valentino Khan',
#  'Ultimate Draft Tips + Eye-Popping Insights - Fantasy Football Podcast': 'Fantasy Footballers - Fantasy Football Podcast',
#  '2:38 A.M.': 'pronouncedyea',
#  'Empty': 'Bajillionaire',
#  'Magical (feat. ZOLLY)': 'Cassian',
#  'I Am No Fun': 'Flawed Mangoes',
#  'Cali': 'De Rien',
#  'Chances': 'Attom',
#  'Where I Want to Be': 'Slater Manzo',
#  "Love Me - Felix Cartal's Chill Mix": 'Felix Cartal',
#  'Air': 'Cub Sport',
#  'I feel alive': 'Duskus',
#  "Ain't Deep Enough - Bonsai Mammal Chill Mix": 'Autograf',
#  'Crystal Castle': 'ICELANDIA',
#  'Dreaming - Demo': 'Two Another',
#  'Wrong for Me': 'Otherwise Fine',
#  'Call Me Up': 'JUNG',
#  'Fractures': 'Anderholm',
#  'Sahara': 'SRFR',
#  'Get to Know Me': 'REAVE',
#  'New Day': 'Benji Lewis',
#  'INDIFFERENT (With Gordi)': 'Willaris. K',
#  'Headlights': 'James Vincent McMorrow',
#  'Stay': 'The Sellouts',
#  'Shelter': 'Richard Fairlie',
#  'Sanity': 'Meynberg',
#  'Who You Are - Mixed': 'KAASI',
#  'Hour Glass': 'Evan Miles',
#  "Can't Stay Away from You": 'cbakl',
#  'Rockshow': 'The Nicholas',
#  'Colour In Your Heart': 'Roo Panes',
#  'This or That ADP Game + Clenching While Drafting': 'Fantasy Footballers - Fantasy Football Podcast',
#  "Say It Loud - I'm Black And I'm Proud": 'James Brown',
#  '16 Shots': 'VIC MENSA',
#  'Alright': 'Kendrick Lamar',
#  'Mad (feat. Lil Wayne)': 'Solange',
#  'A Decade Of Watching Black People Die': 'Code Switch',
#  'Another Irish Drinking Song': 'The Minions',
#  'Hair': 'The Minions',
#  "Make 'Em Laugh": 'The Minions',
#  'Colossus': 'OMAS',
#  'Years Of War': 'Porter Robinson',
#  "She's My Kind Of Crazy": 'Emerson Drive',
#  'Angel Eyes': 'Love and Theft',
#  'Nothing Scares Us (feat. Daniella Mason)': 'Super Duper',
#  'needy': 'Kelsea Ballerini',
#  'Something Like This - Stripped': 'Ukiyo',
#  'Love Me For The Weekend (with Ashe)': 'Party Pupils',
#  'All Night Long': 'Jonas Blue',
#  'I Leave Again': 'Petit Biscuit',
#  'Monday (with Ashe)': 'filous',
#  'Honeybee': 'The Head And The Heart',
#  'Falling': 'Mansionair',
#  'Fantasy State of the Position: Tight End': 'PFF Fantasy Football Podcast with Ian Hartitz',
#  'Arms Length': 'REAVE',
#  '10 Players to Target in the First 10 Rounds of Drafts': 'PFF Fantasy Football Podcast with Ian Hartitz',
#  'Player Prop Bets To Hammer + The Jets Upgraded O-Line': 'PFF Fantasy Football Podcast with Ian Hartitz',
#  "How to Pick Your Keepers + DeAndre Hopkins' 2020 Outlook": 'PFF Fantasy Football Podcast with Ian Hartitz',
#  'My Only Chance': 'The Toxic Avenger',
#  'Make This Right': 'The Toxic Avenger',
#  'Who Am I': 'ARTY',
#  'Free My Mind (with DubDogz) - Joy Corporation Remix': 'Alok',
#  'Get in Trouble (So What)': 'Dimitri Vegas & Like Mike',
#  'Fragile': 'Kygo',
#  'Coming Over (feat. James Hersey)': 'Dillon Francis',
#  'First Time': 'Kygo',
#  'Born To Be Yours': 'Kygo',
#  'Stargazing': 'Kygo',
#  'Electric Feel (Kygo Remix)': 'Henry Green',
#  'Oasis (feat. Foxes)': 'Kygo',
#  'Never Let You Go (feat. John Newman)': 'Kygo',
#  'Prelude': 'SNBRN',
#  'Rewind - Marian Hill Remix': 'Absofacto',
#  'Through the Night': 'Toy Box',
#  'Stubborn': 'Daniel Allan',
#  'Peace - Acoustic': 'Alison Wonderland',
#  'Inevitable': 'MEMBA',
#  'Ur Perfect I Hate It - Lenno Remix': 'Mickey Valen',
#  'Lost & In Love (with The Griswolds)': 'Vincent',
#  'Why': 'Bobby Love',
#  'Tables Have Turned - Dillistone Remix': 'Ralph',
#  'Acetone': 'Landon Conrath',
#  'More - Quiet Storm Version': 'Electric Guest',
#  'Out of Town': 'Janee',
#  'Open (feat. Cailin Russo)': 'Grady',
#  'Skin': 'Manila Killa',
#  'Here With U': 'Michael Mason',
#  'Road to Nowhere': 'Escaping Athena',
#  'Quantum Physics': 'Ruby Waters',
#  'Road Warrior': 'Allan Rayman',
#  'Walk on Water': 'Sembari',
#  'Face Turns Blue': 'Alë Jay',
#  'Pegao A Ti': 'Alë Jay',
#  "doin' to me": 'Alë Jay',
#  'Colours': 'Goth Babe',
#  'Milkshake - Remix': 'St Francis Hotel',
#  '6pm': 'Who',
#  'Overthinking (feat. narou)': 'Bearcubs',
#  'You Should Go': 'Portair',
#  'Long Shot - Mount Pleasant Remix': 'Transviolet',
#  'Balafono': 'Hermitude',
#  'It Never Rains': 'GEO',
#  'Euphoria (feat. Travis Scott & Kaash Paige)': 'Don Toliver',
#  'No Idea - Dj Purpberry Chopped and Screwed': 'Don Toliver',
#  'Woke Up Late (feat. Hailee Steinfeld)': 'Drax Project',
#  'Prefer': 'Drax Project',
#  'Smart Love': 'Drax Project',
#  'Relax': 'Drax Project',
#  'Natural Selection': 'Drax Project',
#  'Brain': 'Drax Project',
#  'Fantasy Wildcards + Cook Holdout, Rebuild Tips - Fantasy Football Podcast': 'Fantasy Footballers - Fantasy Football Podcast',
#  'Roses Remix (feat. Future)': 'SAINt JHN',
#  'Everything Could Change': 'Pin Up',
#  'Keep/Trade/Cut + Hype Train, Excuse Wagons - Fantasy Football Podcast': 'Fantasy Footballers - Fantasy Football Podcast',
#  'Tarzan': 'Armin van Buuren',
#  'Break My Heart - Solardo Remix': 'Dua Lipa',
#  'Tomorrow (feat. 433)': 'Tiësto',
#  'The Last Day': 'City of the Sun',
#  'Heroes': 'Vera Blue',
#  'Warrior': 'Aluna',
#  'World On Fire': 'Denis First',
#  'Expectations (R3HAB Remix)': 'Ella Isaacson',
#  'Tommy Lee (feat. Post Malone)': 'Tyla Yaweh',
#  'Cloud 9 (feat. Jeremih)': 'Afrojack',
#  'All I Need': 'Nora En Pure',
#  'Trap - Rompasso Remix': 'SAINt JHN',
#  'Clorox Wipe': 'Chromeo',
#  '20 Breakout Candidates (Ep. 498)': 'FantasyPros - Fantasy Football Podcast',
#  'La Luz': 'City of the Sun',
#  'Young Folks': 'City of the Sun',
#  'While We Are Young': 'City of the Sun',
#  'Dreams': 'City of the Sun',
#  'Spaghetti': 'City of the Sun',
#  'Brothers': 'City of the Sun',
#  'To the Sun and All the Cities in Between': 'City of the Sun',
#  'Those Days Are Now': 'City of the Sun',
#  'Dance of the Dead': 'City of the Sun',
#  'Imagination': 'City of the Sun',
#  'Interlude': 'City of the Sun',
#  'W. 16th St': 'City of the Sun',
#  'La Puerta Roja': 'City of the Sun',
#  'Winter 2011': 'City of the Sun',
#  'Top 15 Bounce-Back Candidates (Ep. 499)': 'FantasyPros - Fantasy Football Podcast',
#  'Hindsight': 'Tom Martin',
#  'The Fool': 'Jerro',
#  'go with u': 'BAYNK',
#  "Can't Let Go (feat. Harry Hudson)": 'Frank Walker',
#  'Pink & Blue (RAC Mix)': 'Tycho',
#  'Wake up with You': 'Emerson Leif',
#  'Way Up': 'Fintan',
#  'Another Light (Cyril Hahn Remix)': 'Henry Green',
#  'When Am I Gonna Lose You - Medasin Remix': 'Local Natives',
#  "Don't Wanna Miss You": 'Ehrling',
#  'Chateau': 'Petit Biscuit',
#  'Roll Back - TOKiMONSTA Remix': 'George FitzGerald',
#  'just listen': 'Sabastian',
#  'Skip': 'ARAI',
#  'Lay Your Head On Me (feat. Marcus Mumford) [Acoustic]': 'Major Lazer',
#  'I Will Wait': 'Mumford & Sons',
#  'Little Lion Man': 'Mumford & Sons',
#  'The Cave': 'Mumford & Sons',
#  'Toronto': 'Polythought',
#  'Kids in America (feat. Panama)': 'Manu Dia',
#  'Giver': 'Módl',
#  'Thoughts': 'Holz',
#  'Bummed (feat. Alison Wonderland)': 'Chet Porter',
#  'Trading Places': 'Juke Ross',
#  'Take Your Time': 'Boulevarde',
#  'White Flashes': 'Among Savages',
#  'State of the Art': 'JMR',
#  'See You in My Dreams': 'Wisemind',
#  'Running - TELYKast Remix': 'Arlissa',
#  'New York': 'Jake Isaac',
#  'Hide and Seek - Don Diablo Edit': 'Danny Olson',
#  "Thinking 'Bout Love": 'Wild Rivers',
#  'A Total Dream': 'Charles Fauna',
#  'Not Ok - Frank Walker Remix': 'Kygo',
#  'Piano': 'Frank Walker',
#  "I'm Not Alright - Frank Walker Remix": 'Loud Luxury',
#  'Good to You': 'Bright Sparks',
#  'Stay Forever': 'Ehrling',
#  'More Than OK': 'R3HAB',
#  'Family - Frank Walker Remix': 'The Chainsmokers',
#  'Sleep In - Pryces Remix': 'Ukiyo',
#  'Slack': 'ford.',
#  'Give It to Me': 'HOMESHAKE',
#  'Surface': 'Race Banyon',
#  'Salt': 'B.Miles',
#  'Pain Goes Away': 'Refs',
#  'Something': 'Cyn',
#  'All in the Value': 'HONNE',
#  'Stranger / Lover (Mura Masa Remix)': 'Ibeyi',
#  'Raindrops': 'Moglebaum',
#  'Bloom': 'IHF',
#  'Radar (feat. HONNE)': 'Whethan',
#  'Arc-en-ciel': 'Polo & Pan',
#  'Swing Swing': 'ayokay',
#  'Treat You Better - Cassian Remix': 'RÜFÜS DU SOL',
#  'Throwaway (with Clairo)': 'SG Lewis',
#  'Encore': 'Magnificence',
#  'Forever Yours': 'dj poolboi',
#  'Places We Don’t Know - ford. Remix': 'Kasbo',
#  'Thin Floors And Tall Ceilings - ford. Remix': 'ODESZA',
#  'Wonders of the Unknown': 'Behind Clouds',
#  'Lonely': 'Idealism',
#  'Lilacs': 'dj poolboi',
#  "it's alright now": 'dj poolboi',
#  'controlla': 'Idealism',
#  'tsuyu': 'Idealism',
#  'CUPID - Lehvi Remix': 'dvdkm',
#  'Lazy Sad': 'ford.',
#  'Echoes': 'Roam',
#  'Freak': 'JIL',
#  'Many Words - Goslo Remix': 'DROELOE',
#  'TROJAN HORSE': 'SEBASTIAN PAUL',
#  'Never': 'Bronze Whale',
#  'Me and My Friends - CRi Remix': 'CRi',
#  'Holiday (Off the Edge)': 'On Planets',
#  'The Ride': 'Steve Pad',
#  'Flow': 'Crooked Colours',
#  'All Your Love': 'Flight Facilities',
#  'Razon': 'City of the Sun',
#  'You and I...and New York': 'City of the Sun',
#  'Ambivalence': 'Hanz',
#  'Warmth': 'ford.',
#  "Don't Miss It": 'James Blake',
#  'Fondness': 'Late June',
#  'Get Lost - Ford. Remix': 'Bearson',
#  'Higher': 'Draper',
#  'Sugar': 'City of the Sun',
#  'No Walls In The West': 'City of the Sun',
#  'Standing Rock': 'City of the Sun',
#  'Barcelona': 'City of the Sun',
#  'Paco': 'City of the Sun',
#  'Firefly': 'City of the Sun',
#  '24 Most Overvalued & Undervalued Players (Ep. 502)': 'FantasyPros - Fantasy Football Podcast',
#  'Thousand Faces': 'Don Diablo',
#  'Boom Boom': 'Armin van Buuren',
#  'Feel Good': 'Polo & Pan',
#  'Gunshots': 'Gareth Emery',
#  'Together Forever': 'Moon Boots',
#  'A happy memorial': 'Slumberville',
#  'U Move, I Move (feat. Jhene Aiko)': 'John Legend',
#  'Colour Me': 'Juke Ross',
#  'Fresh Roses': 'Juke Ross',
#  'POW POW POW': 'Kaskade',
#  'My People': 'Amber Mark',
#  'Lose My Cool': 'Amber Mark',
#  'All Night (feat. Ally Brooke) - Chico Rose Extended Remix': 'Afrojack',
#  'Midnight (feat. Liam Payne) (Jack Wins Remix)': 'Alesso',
#  'No Lie - HUGEL Remix': 'Michael Calfan',
#  'Sunset Lover': 'Petit Biscuit',
#  'Take Me Away': 'Scotty Sire',
#  'Boom': 'Zane Hijazi',
#  'Cap (feat. Offset)': 'KSI',
#  'Poppin (feat. Lil Pump & Smokepurpp)': 'KSI',
#  'Millions': 'KSI',
#  'Outlaw': 'Heath Hussar',
#  'Two Thousand and Seventeen': 'Four Tet',
#  'Teenage Birdsong': 'Four Tet',
#  'Prism': 'Tim Hecker',
#  'Utropics': 'Tim Hecker',
#  'Borderlands': 'Tim Hecker',
#  'Sketch 4': 'Tim Hecker',
#  'Amps, Drugs, Harmonium': 'Tim Hecker',
#  'Sketch 1': 'Tim Hecker',
#  'Bijie Dream': 'Tim Hecker',
#  'Sketch 7': 'Tim Hecker',
#  'Sea of Pulses': 'Tim Hecker',
#  'Hatred of Music I': 'Tim Hecker',
#  'Grey Geisha': 'Tim Hecker',
#  'Obsidian Counterpoint': 'Tim Hecker',
#  'Step away from Konoyo': 'Tim Hecker',
#  'Is but a simulated blur': 'Tim Hecker',
#  'Keyed out': 'Tim Hecker',
#  'In the Air I': 'Tim Hecker',
#  'Feel Good Inc.': 'Gorillaz',
#  'Some Kind of Nature (feat. Lou Reed)': 'Gorillaz',
#  'Top 10 Fantasy Football Fades (Ep. 497)': 'FantasyPros - Fantasy Football Podcast',
#  'PPR Mock Draft (Ep. 501)': 'FantasyPros - Fantasy Football Podcast',
#  'Early Breakouts & Busts - Fantasy Football Podcast': 'Fantasy Footballers - Fantasy Football Podcast',
#  'Calvin Ridley milk and honey': 'RotoUnderworld Radio - Fantasy Football Show',
#  'Lush': 'Four Tet',
#  'Daughter': 'Four Tet',
#  'Baby': 'Four Tet',
#  'Locked': 'Four Tet',
#  'School': 'Four Tet',
#  '#162 The Least You Could Do': 'Reply All',
#  '1998 - Mixed': 'Chet Faker',
#  'No Diggity': 'Chet Faker',
#  'Drop The Game': 'Flume',
#  'What About Us': 'Flume',
#  'This Song Is Not About A Girl': 'Flume',
#  '1998': 'Chet Faker',
#  'Gold': 'Chet Faker',
#  'Talk Is Cheap': 'Chet Faker',
#  'Dive': 'Zes',
#  "Can't Move On": 'Chillhum',
#  'Dreamcatcher': 'Robotaki',
#  'KILLING TIME - Acoustic': 'The Kite String Tangle',
#  'Suncats': 'Hazlett',
#  'Trust': 'Prince Fox',
#  'Running': 'demotapes',
#  'No Signal': 'Forester',
#  'Goodbye (feat. Meredith Brackbill & Galvanic)': 'Emerald Lake',
#  'Run for Me': 'SebastiAn',
#  'Kyle (I Found You)': 'Fred again..',
#  'All Mine (feat. Eleven) - Bonjr Remix': 'Sense',
#  'Easy': 'Kody Ryan',
#  'Something Familiar': 'ayokay',
#  'How Did We Get Here': 'offrami',
#  'Ella': 'Kendl',
#  'Cloudburst': 'Flow Loris',
#  'Yasmin you will never hear this': 'Mikey Mike',
#  'Have My Back': 'Kyson',
#  'Alive': 'HOFFEY',
#  'iinterlude 1': 'OTHERLiiNE',
#  'Up to You': 'Dreamsuite',
#  'Read All About It, Pt. III': 'Stefan Biniak',
#  'Be Free': 'MALFNKTION',
#  'Early Sleepers & Values - Fantasy Football Podcast': 'Fantasy Footballers - Fantasy Football Podcast',
#  'Daylight': 'Jome',
#  'Gleams': 'fugue',
#  'Young & Alive': 'Bazzi',
#  'All Night Long - Y.V.E. 48 Remix': 'Nora Van Elken',
#  'Wellspring': 'VOLO',
#  'Sports Car': 'Valley',
#  'Waiting': 'Autograf',
#  "There's Still A Light In The House": 'Valley',
#  "There's Still A Light In The House - Chill Mix": 'Valley',
#  'Pretty Life': 'Terrell Morris',
#  'Familiar Faces': 'Terrell Morris',
#  'Toi': 'Terrell Morris',
#  'Free Problems': 'Terrell Morris',
#  'Me 4 Prez': 'Terrell Morris',
#  'Oak (feat. Basecamp)': 'Terrell Morris',
#  'Make You': 'Terrell Morris',
#  '10 Boom or Bust Players + Best Dynasty Draft Bargains (Ep. 504)': 'FantasyPros - Fantasy Football Podcast',
#  'A Phone Call In Amsterdam': 'Valley',
#  'Park Bench': 'Valley',
#  'Harpsichord': 'Four Tet',
#  'Romantics': 'Four Tet',
#  'Love Salad': 'Four Tet',
#  'Insect Near Piha Beach': 'Four Tet',
#  'Hi Hello': 'Four Tet',
#  'ISTM': 'Four Tet',
#  'Something in the Sadness': 'Four Tet',
#  '1993 Band Practice': 'Four Tet',
#  'Green': 'Four Tet',
#  'Bubbles at Overlook 25th March 2019': 'Four Tet',
#  '4T Recordings': 'Four Tet',
#  'This Is for You': 'Four Tet',
#  'Mama Teaches Sanskrit': 'Four Tet',
#  'Alap': 'Four Tet',
#  'LA Trance': 'Four Tet',
#  'Tremper': 'Four Tet',
#  'Scientists': 'Four Tet',
#  'Falls 2': 'Four Tet',
#  'You Are Loved': 'Four Tet',
#  'SW9 9SL': 'Four Tet',
#  '10 Midi': 'Four Tet',
#  'Memories': 'Four Tet',
#  'Big Love (with EARTHGANG & MNDR)': 'Louis The Child',
#  'Touch - Poolside Remix': 'Big Wild',
#  'Hollow': 'Armin van Buuren',
#  'Tonight': 'Ehrling',
#  'Love Somebody': 'Lauv',
#  'Hold On': 'ford.',
#  'Heaven': 'Cheat Codes',
#  'Nightcrawler - Illyus & Barrientos Remix': 'Duke Dumont',
#  'Sundae': 'Moon Boots',
#  'Medusa': 'GRiZ',
#  'The Worship': 'AVIRA',
#  'Looking For Me': 'Paul Woolford',
#  'Lose You - Chico Rose Remix': 'Tiësto',
#  'The Difference - Willaris. K Remix': 'Flume',
#  'Bad News Baby - Acoustic': 'ALMA',
#  'Everything Everywhere Matters To Everything': 'City of the Sun',
#  'Matthew Mcconaughey': 'Shwayze',
#  'Nowhere': 'Borgeous',
#  'Forget Your Body.': 'Ben Zaidi',
#  'Trust Nobody': 'DJ Snake',
#  'Pretty Girl - Cheat Codes X CADE Remix': 'Maggie Lindemann',
#  'Future Humans': 'The North Country',
#  'Signs and Wonders': 'The North Country',
#  "Don't Quit Your Day Job": 'The North Country',
#  'Running Around': 'The North Country',
#  'The Prawn Song': 'Superorganism',
#  'The Flood': 'The North Country',
#  'Dune': 'The North Country',
#  'Open for Business': 'The North Country',
#  'Rosyln': 'Bon Iver',
#  'In the Woods': 'The North Country',
#  'Chains of Love (On Prisoners of War)': 'The North Country',
#  'First Round Draft Advice + 10 Late-Round Must-Haves (Ep. 505)': 'FantasyPros - Fantasy Football Podcast',
#  'The Times Are Tired': 'Alaskan Tapes',
#  '15 Scorching Hot Takes (Ep. 503)': 'FantasyPros - Fantasy Football Podcast',
#  'Chemicals': 'SG Lewis',
#  'Flames (feat. Ruel)': 'SG Lewis',
#  'Hurting (feat. AlunaGeorge)': 'SG Lewis',
#  'Orange Juice': 'Lostboycrow',
#  'Chasing Feelings': 'Buttered',
#  'Feenicks': 'Szymon',
#  'Weightless': 'King Monday',
#  'Reset': 'SLUMB',
#  'Find Love': 'Kaskade',
#  'Oak': 'Khotton Palm',
#  'Find Me': 'Trinix',
#  'Fatale': 'Nick AM',
#  'Madness': 'Orange Dream',
#  'Costello Ave': 'TRAILS',
#  'Basis': 'Oruam',
#  'Let The Light In': 'Will Hearn',
#  'Youuu': 'COIN',
#  "Everybody's Got to Learn Sometime (Tentendo Remix)": 'YesYou',
#  'Dip Interlude': 'Terrell Morris',
#  'Levvi': 'Terrell Morris',
#  'PRBLMS': '6LACK',
#  'ATL Freestyle': '6LACK',
#  'Long Nights': '6LACK',
#  'Float': '6LACK',
#  'Know My Rights (feat. Lil Baby)': '6LACK',
#  'Elephant In The Room': '6LACK',
#  'Outside': '6LACK',
#  '21 Days': 'Geoffroy',
#  'Close': 'informal.',
#  'Sleeping on My Own': 'Geoffroy',
#  'Feel': 'Luke Marzec',
#  'The Small Things': 'Conro',
#  'Sudden Changes': 'Niva',
#  'Demand': 'Iawo',
#  'Calm Down': 'Mammals',
#  'With You - Bronze Whale Remix': 'Felix Cartal',
#  'Clouds': 'IHF',
#  'Departure': 'IHF',
#  "Booty-Scootin' Cam Newton + Hold Em' or Fold Em' - Fantasy Football Podcast": 'Fantasy Footballers - Fantasy Football Podcast',
#  'Holy Water': 'Abby Sage',
#  'Left Behind the Gold': 'Cards',
#  '20 Players to Avoid This Year (Ep. 506)': 'FantasyPros - Fantasy Football Podcast',
#  'Sherane a.k.a Master Splinter’s Daughter': 'Kendrick Lamar',
#  'Bitch, Don’t Kill My Vibe': 'Kendrick Lamar',
#  'Backseat Freestyle': 'Kendrick Lamar',
#  'The Art of Peer Pressure': 'Kendrick Lamar',
#  'Money Trees': 'Kendrick Lamar',
#  'Happy?': 'Caye',
#  'Heart': 'OTR',
#  "6's to 9's (feat. Rationale)": 'Big Wild',
#  'Americans': 'Molly Parton',
#  'Mid-Round RB Rundown + Coaching Changes & Impact (Ep. 507)': 'FantasyPros - Fantasy Football Podcast',
#  'DAWN (feat. Totally Enormous Extinct Dinosaurs) - Edit': 'BRONSON',
#  'My House': 'Elderbrook',
#  'Horyzon': 'ARTY',
#  'Heat Waves': 'Glass Animals',
#  'Ego Death (feat. Kanye West, FKA twigs & Skrillex)': 'Ty Dolla $ign',
#  'Oversupply': 'Michael Dunstan',
#  'Sad About It': 'Gill Chang',
#  'Young Lovers': 'Dutchkid',
#  'Vertigo': 'Mushroom People',
#  'Feels Like': 'HRDLY',
#  'Buttons': 'meija',
#  'Ku Ring Gai': 'Daktyl',
#  'Zorah Come Home': 'Jadu Heart',
#  'I Need A Forest Fire': 'Lani Rose',
#  'Catching Eyes': '49th & Main',
#  '“Tesla is a 14-year-old LeBron James” — Lemonade goes public. Tesla > Toyota. Walmart’s drive-in movies. ': 'Snacks Daily',
#  'Equinox': 'Brandon',
#  'Birds': 'Kama',
#  'No Good For You (feat. Jaymes Young)': 'Keenan',
#  'Warm Animal - Acoustic': 'Sure Sure',
#  'Gone Again': 'Kevin Garrett',
#  'Tomorrow': 'Fjun',
#  'Lost Like Us': 'Lost Frequencies',
#  'Stringsnoise': 'Samuel Proffitt',
#  'Home': 'Fortuno',
#  'Nemesis': 'Astrolemo',
#  '93': 'Hans Williams',
#  'Love That Never': 'TOKiMONSTA',
#  'Still Here': 'Kllo',
#  "I Don't Want This Job": 'Zach Winters',
#  'Aquiver': 'Le Youth',
#  'Next to You': 'New West',
#  'Overview Effect 1972': 'The Geek x Vrv',
#  'At Sea - Godwolf Remix': 'Flamingo',
#  'Breathe': 'Ed.1t',
#  'Half-PPR Mock Draft w/ Chris Raybon (Ep. 508)': 'FantasyPros - Fantasy Football Podcast',
#  'Bounce Back Players + Mahomes Extension, Hang Gliding - Fantasy Football Podcast': 'Fantasy Footballers - Fantasy Football Podcast',
#  'WHATS POPPIN': 'Jack Harlow',
#  'Dreamer': 'Four Tet',
#  'Never Come Back - Four Tet Remix': 'Caribou',
#  '3AM': 'Russ',
#  'Gong': 'Four Tet',
#  'Parallel Jalebi': 'Four Tet',
#  'Our Navigation': 'Four Tet',
#  'Ba Teaches Yoga': 'Four Tet',
#  'Kool FM': 'Four Tet',
#  'Crush': 'Four Tet',
#  'Buchla': 'Four Tet',
#  'I Need You To Know': 'Armin van Buuren',
#  'Lucid Dreams': 'Juice WRLD',
#  'i saw your face': 'Gareth Emery',
#  'My Rajneesh': 'Sufjan Stevens',
#  "Fallin' In": 'Mike Williams',
#  'Ocean Drive - Purple Disco Machine Remix': 'Duke Dumont',
#  "Don't Cry For Me (with Jason Derulo)": 'Alok',
#  'America': 'Sufjan Stevens',
#  'The Ghost Burns (TOKiMONSTA Remix)': 'TOKiMONSTA',
#  'Am I High Rn (feat. blackbear)': 'Quinn XCII',
#  'Alane - Don Diablo Remix': 'Robin Schulz',
#  'Alane': 'Robin Schulz',
#  'Wait Another Day': 'Mike Williams',
#  'Another Night (feat. Matluck) - Acoustic Version': 'Mike Williams',
#  'Be Like That - feat. Swae Lee & Khalid': 'Kane Brown',
#  'Another Night (feat. Matluck)': 'Mike Williams',
#  'Another Night on Mars': 'The Maine',
#  'The Beat': 'Mike Williams',
#  'AFC North Breakdown + Double Jump, Buy or Sell - Fantasy Football Podcast': 'Fantasy Footballers - Fantasy Football Podcast',
#  'So Close': 'NOTD',
#  'I Wanna Know (feat. Bea Miller)': 'NOTD',
#  'Keep You Mine': 'NOTD',
#  'I Miss Myself (with HRVY)': 'NOTD',
#  'Wanted': 'NOTD',
#  'Beautiful People (feat. Khalid) - NOTD Remix': 'Ed Sheeran',
#  'Been There Done That (feat. Tove Styrke)': 'NOTD',
#  'Post Malone (feat. RANI)': 'Sam Feldt',
#  "There's Nothing Holdin' Me Back - NOTD Remix": 'Shawn Mendes',
#  'Romantic - NOTD Remix': 'Stanaj',
#  'Control - NOTD Remix': 'Zoe Wees',
#  '18 Undervalued Studs (Ep. 509)': 'FantasyPros - Fantasy Football Podcast',
#  'Shape of You - NOTD Remix': 'Ed Sheeran',
#  'Summer Of Love': 'NOTD',
#  'Selfish': 'Madison Beer',
#  'Right Now - GATTÜSO Remix': 'VAVO',
#  'Missing Home - filous remix': 'flora cash',
#  'Big Time - X Games Theme': 'Louis The Child',
#  'Alone': 'Prince Fox',
#  "I Can't Help": 'Shoffy',
#  '15 Potential Rankings Risers + Fantasy Odd Man Out w/ Sean Koerner (Ep. 510)': 'FantasyPros - Fantasy Football Podcast',
#  'Slow Cycle': 'Blutch',
#  'idontwannaknow': 'Beauvois',
#  'The Kite (Outro)': 'Blonde Maze',
#  '20 Deep Sleepers (Ep. 511)': 'FantasyPros - Fantasy Football Podcast',
#  'Monday Blues - Radio Edit': 'Eric Sharp',
#  'Atoms - Said the Sky Remix': 'RL Grime',
#  'Foundations': 'KOLIDESCOPES',
#  'Honest': 'San Holo',
#  'Honey': 'Disco Lines',
#  'April': 'Jonas Langer',
#  'Rainwater': 'Past Palms',
#  'Found': 'Align',
#  'Be Slow': 'Harrison Storm',
#  'In Another Life': 'Active Child',
#  'Move That': 'Headphone Activist',
#  'Save Me': 'Amitė',
#  'Most People': 'Jerry Folk',
#  'Hold Me Tonight': 'BYNON',
#  'No Roof Access': 'Kyle Lux',
#  'Farenag': 'Cosmopolitan Harbor',
#  "Mind's Eye": 'Hugo Mari',
#  'Flamingo': 'Astronomyy',
#  'Ocean Eyes - Astronomyy Remix': 'Billie Eilish',
#  'Dust': 'Komplement',
#  'CEH No Matter What - Ft. Graham Barfield & Scott Barrett ': 'The Breakout Finder Network',
#  'Raheem Mostert trust fall': 'RotoUnderworld Radio - Fantasy Football Show',
#  'Cool For A Second': 'Yumi Zouma',
#  'Life On Mars': 'Adrian Lux',
#  'Cherie': 'Sorrow',
#  'Alpine': 'OCULA',
#  'Imperfection': 'Cella',
#  'Pressure (with SG Lewis)': 'James Vickery',
#  'What I Know': 'cln',
#  'This Place': 'obylx',
#  'Hypnotized': 'Astronomyy',
#  "Things I'd Do for U": 'Astronomyy',
#  "Don't Need U": 'Astronomyy',
#  "Everythin' on My Mind": 'Astronomyy',
#  'Rest in Paradise': 'Astronomyy',
#  'Long Shadow, Short Temper': 'Fat Night',
#  'Woof': 'Sen Morimoto',
#  'AFC West Breakdown + Henry Gets Paid - Fantasy Football Podcast': 'Fantasy Footballers - Fantasy Football Podcast',
#  "What's Love Got to Do with It": 'Kygo',
#  'Aftertaste (Mixed)': 'Loud Luxury',
#  'Hold You Tonight (with Chris Lane) - Acoustic': 'Gryffin',
#  'Desire - Single Edit': 'Bob Moses',
#  'Kill Me Slow': 'David Guetta',
#  'Jam': 'Above & Beyond',
#  '5 Seconds Before Sunrise': 'VER:WEST',
#  'Funny': 'Zedd',
#  'Hate Me': 'Shwayze',
#  'Imagine': 'Steve Aoki',
#  'Thinking About You (with Winona Oak)': 'R3HAB',
#  'Crazy': 'Mike Perry',
#  'Get Your Wish - Anamanaguchi Remix': 'Porter Robinson',
#  'The Middle': 'Zedd',
#  'Get Low (with Liam Payne)': 'Zedd',
#  'Happy Now': 'Zedd',
#  'Clarity': 'Zedd',
#  'Delta': 'Nora En Pure',
#  'Let Her Go': 'Passenger',
#  "Like I'm Gonna Lose You": 'Jasmine Thompson',
#  'You Are My Sunshine': 'Jasmine Thompson',
#  'Rather Be': 'Jasmine Thompson',
#  "Ain't Nobody (Loves Me Better) - Acoustic": 'Jasmine Thompson',
#  "Ain't Nobody (Loves Me Better) (feat. Jasmine Thompson)": 'Felix Jaehn',
#  'Willow': 'Jasmine Thompson',
#  'Mad World': 'Jasmine Thompson',
#  'I Try': 'Jasmine Thompson',
#  'Old Friends': 'Jasmine Thompson',
#  'Everything Has Changed': 'Jasmine Thompson',
#  '7 Years': 'Jasmine Thompson',
#  'Almost Lover': 'Jasmine Thompson',
#  'Will Follow You Into the Dark': 'Jasmine Thompson',
#  'Adore': 'Jasmine Thompson',
#  'Holding You Close': 'Ryan Pulford',
#  'I Want You To Know': 'Zedd',
#  'Beautiful Now': 'Zedd',
#  'Blinding Lights': 'The Weeknd',
#  'Muirfield': 'Don Lifted',
#  '30000': 'Westerns',
#  'Yellow': 'Emmit Fenn',
#  'Somebody': 'The Chainsmokers',
#  'Lifetime': 'Zonderling',
#  'Reality': 'Lost Frequencies',
#  'Pinkman - Instrumental mix': 'Frank Ocean (IT)',
#  'Aurora': 'David Scott',
#  'Lovelike': 'SAINT WKND',
#  'sunday': 'Joy Oladokun',
#  'ONDAWAY': 'the44thfloor',
#  'Something More': 'Yula',
#  "Don't Mind That We're Lonely": 'Calundé',
#  'Keep It Simple (feat. Wilder Woods) - Rayet Remix': 'Matoma',
#  'Move Me': 'Liyr',
#  'Do It Better': 'Frents',
#  'Open End Resource - Leaving Laurel Remix': 'Andrew Bayer',
#  'Up in Flames': 'Łaszewo',
#  'Losing Myself': 'Shui & Denae',
#  'You Got Me': 'Dillistone',
#  'Friday - OKO Remix': 'King Topher',
#  'Right Way': 'Attic Beats',
#  'Life Is So Beautiful': 'Sofasound',
#  'Breakfast in Bed': 'Joshua Singh',
#  '21 Tips for Draft Domination (Ep. 513)': 'FantasyPros - Fantasy Football Podcast',
#  'Best Kept Secrets, Last Place Punishments + The NFL & Coronavirus - Fantasy Football Podcast': 'Fantasy Footballers - Fantasy Football Podcast',
#  'Lucy In The Sky With Diamonds - Remastered 2009': 'The Beatles',
#  'Getting Better - Remastered 2009': 'The Beatles',
#  'Fixing A Hole - Remastered 2009': 'The Beatles',
#  "She's Leaving Home - Remastered 2009": 'The Beatles',
#  'Being For The Benefit Of Mr. Kite! - Remastered 2009': 'The Beatles',
#  'Within You Without You - Remastered 2009': 'The Beatles',
#  "When I'm Sixty Four - Remastered 2009": 'The Beatles',
#  'Lovely Rita - Remastered 2009': 'The Beatles',
#  'Good Morning Good Morning - Remastered 2009': 'The Beatles',
#  "Sgt. Pepper's Lonely Hearts Club Band - Reprise / Remastered 2009": 'The Beatles',
#  'A Day In The Life - Remastered 2009': 'The Beatles',
#  "Sgt. Pepper's Lonely Hearts Club Band - Remastered 2009": 'The Beatles',
#  'With A Little Help From My Friends - Remastered 2009': 'The Beatles',
#  'Steady 1234 (feat. Jasmine Thompson & Skizzy Mars)': 'Vice',
#  'Kickback': 'Myles Parrish',
#  'Drop Your Guard': 'Jasmine Thompson',
#  'Royals': 'Jasmine Thompson',
#  'Wrecking Ball': 'Jasmine Thompson',
#  'Demons': 'Jasmine Thompson',
#  'A Thousand Years': 'Jasmine Thompson',
#  'Not About Angels': 'Jasmine Thompson',
#  'Breathe Me': 'Jasmine Thompson',
#  'Say Something': 'Jasmine Thompson',
#  'All of Me': 'Jasmine Thompson',
#  'I See Fire': 'Jasmine Thompson',
#  'Everybody Hurts': 'Jasmine Thompson',
#  'La la La': 'Jasmine Thompson',
#  'PPR Mock Draft w/ Adam Rank (Ep. 514)': 'FantasyPros - Fantasy Football Podcast',
#  'In Your Eyes': 'The Weeknd',
#  'All My Friends': 'LCD Soundsystem',
#  'iSpy (feat. Lil Yachty)': 'KYLE',
#  'Hurting on Purpose (feat. K.Flay)': 'Whethan',
#  'KEEP MOVING': 'BRONSON',
#  'Embers': 'Ehrling',
#  'Savage (feat. Flux Pavilion & MAX)': 'Whethan',
#  ...}

# %% [markdown]
# ## Counting the Number of Plays per Track
# We'll now create a dictionary of the number of times each track in the total listening history was played. We'll merge this to our full data frame of tracks on the track name prior to our analysis.

# %%
# Loop over the list of dictionaries and if the trackName is not in our count dictionary, add it and set value to one.
# If it is in the dictionary, increase the value by 1.
track_count_dict = {}
for item in streaming_list:
    if item['trackName'] in track_count_dict:
        track_count_dict[item['trackName']] += 1
    else:
        track_count_dict[item['trackName']] = 1
track_count_dict
# Out:
# {'Roses - Imanbek Remix': 16,
#  'In My Soul': 8,
#  'Me Tonight': 10,
#  'Like It Is': 8,
#  'Breathe, Be Happy - French Braids Remix': 5,
#  'One Last Time': 7,
#  'Born To Love (feat. SHELLS)': 6,
#  'Home (Leave the Lights On)': 35,
#  'Little Less Polite': 6,
#  'Hoops - Acoustic': 9,
#  'Hoops': 7,
#  'Everytime': 4,
#  'Love Is Alive (feat. Elohim) - Chet Porter Remix': 4,
#  "Sure Don't Miss You (feat. The Dip)": 7,
#  'Backup': 5,
#  'Heartless (with Julia Michaels & Morgan Wallen)': 7,
#  'Freaks': 8,
#  'Line Of Sight - Chet Porter Remix': 5,
#  'Modern Loneliness': 22,
#  'The Difference': 5,
#  'HEART ATTACK (feat. lau.ra)': 26,
#  'Joe': 9,
#  'Paradise': 2,
#  'Memories That You Call (feat. Monsoonsiren) - ODESZA & Golden Features VIP Remix': 1,
#  'VAULTS': 19,
#  "Don't Let Me Down": 15,
#  'Coffee': 1,
#  'Astral Haven - Paul Arcane Remix': 1,
#  'Need Your Love (feat. Noah Kahan) - Nurko Remix': 1,
#  'Every Color (with Foster The People)': 2,
#  '1894': 1,
#  'F&MU': 1,
#  "I'm Just Feelin' (Du Du Du)": 2,
#  'Older - Felix Cartal Remix': 1,
#  'I Love My Friends - Armin van Buuren & Avian Grays Remix': 1,
#  'Freak Like Me (feat. Kate Wild)': 1,
#  'We’re All In This Together (Push The Button) [ABGT378] - Above & Beyond Respray': 1,
#  'Sour Candy': 7,
#  'It Ain’t Me (with Selena Gomez)': 6,
#  'Rushing Back': 5,
#  'Light up for You - Acoustic': 1,
#  'Better Now': 1,
#  'Us': 1,
#  'Tell Me': 1,
#  'Her Touch': 9,
#  'Inside of My Eyelids': 1,
#  'If The World Was Ending (feat. Julia Michaels) - Madism Remix': 1,
#  'If the World Was Ending - feat. Julia Michaels': 9,
#  'Tadow': 59,
#  'FISA Follies & Trump’s Taxes (with Steve Vladeck)': 1,
#  'Silk...': 1,
#  'I Had A Vision': 1,
#  'Lavish Lullaby': 6,
#  'Old Age': 1,
#  'Prone': 1,
#  'Sugar Walls': 1,
#  'Queen Tings': 2,
#  'Just A Little': 1,
#  "Shawty Fishin' (Blame The Net)": 1,
#  'The Scaredy Cats Horror Show': 3,
#  'Veg Out (Wasting Thyme)': 1,
#  'Need It': 1,
#  'Flight 99': 1,
#  'Under The Wind': 6,
#  'Safe And Sound': 5,
#  'alpha waves': 16,
#  'Mil Sonidos': 13,
#  'Heavenly Father (feat. Noah Kahan) - Recorded at Electric Lady Studios, NYC': 1,
#  'Love Like That': 2,
#  'Make It Right - Trinix Remix': 3,
#  'Make It Right': 1,
#  'Right Time': 10,
#  'Rebellious': 1,
#  'Beyond the Senses - Bliss Remix': 1,
#  'Call Me, I Still Love You - Extended Version': 2,
#  'Amanecer': 1,
#  "I Don't Know Why": 12,
#  'Dreamland': 5,
#  'Draft Recap ': 1,
#  'Proud (feat. Daecolm) [Dogma Remix]': 1,
#  'The Baddest': 1,
#  'Come Away': 1,
#  'In Your Arms (with X Ambassadors) [Alan Walker Remix]': 1,
#  'Let It Go (feat. Anna Clendening)': 1,
#  'Sway': 1,
#  'Together': 4,
#  'Bloom - Bonus Track': 32,
#  'Minimum': 35,
#  'Flaws': 35,
#  'The Night We Met (feat. Phoebe Bridgers)': 28,
#  'Conversation': 27,
#  'Fallingwater': 27,
#  'Alaska - Acoustic': 25,
#  'Godmanchester Chinese Bridge - Radio Edit': 24,
#  'Feels Like This': 58,
#  'Half the World Away': 24,
#  'Decatur, or, Round of Applause for Your Step-Mother!': 24,
#  'The Funeral': 6,
#  'Brownstone Alley': 24,
#  'Dangerous - Cleopold Remix': 8,
#  'Windows': 4,
#  'Need You': 10,
#  'Trails': 3,
#  'All I Want': 3,
#  'Know Love - OTR Remix': 4,
#  'All Love': 3,
#  "Don't Let Them - Flyboy Remix": 4,
#  'higher': 3,
#  'Jetlag Love': 3,
#  'Needs': 3,
#  'The Feeling Is All Gone': 3,
#  'Morning': 35,
#  'High (Remix)': 3,
#  'we try': 3,
#  "And Then We'll Be Alright": 3,
#  'Call It Off': 3,
#  'Busy': 2,
#  'Painter': 2,
#  'Take Me': 2,
#  'Not December': 2,
#  'Friends': 4,
#  'Skeletons': 2,
#  '6 ft.': 2,
#  'Tender': 2,
#  'Tucson': 10,
#  'Before the New': 2,
#  'When It Rains': 2,
#  'No Return': 2,
#  'Kintsugi': 2,
#  'Survivors - Acoustic': 23,
#  'Reckless': 8,
#  'Nikes On': 1,
#  'Dawning': 12,
#  'What You Love You Must Love Now': 13,
#  'Five in the Morning': 1,
#  'Curiosity': 10,
#  'Coda': 10,
#  'When They Come': 7,
#  'Just Look at You': 11,
#  'Event Horizon': 6,
#  'Laugavegur': 9,
#  'Monumental': 8,
#  'Den inre skogen': 8,
#  'The Discovery': 8,
#  'Target': 5,
#  'Awaken': 11,
#  'Bouquet with Lilies': 7,
#  'Eidolon': 7,
#  'Escaping Time': 12,
#  'Collapse Into Light': 7,
#  'The Disappearance of the Unmoved Mover': 6,
#  'Ingénue': 7,
#  'Adrift': 6,
#  'Limitless': 6,
#  'Another Mellow Morning': 4,
#  'Pour Up': 3,
#  'Radiant': 1,
#  'Drown (feat. Clinton Kane)': 2,
#  "I'll Wait": 5,
#  'You Are the One': 25,
#  'Bulletproof': 4,
#  'Biggest Dynasty Differences, Rankings & Trade Values - Fantasy Football Podcast': 2,
#  'Touch': 10,
#  'Friends - Party Pupils Remix': 3,
#  'go with u - Louis La Roche Remix': 6,
#  'Hold Me Close': 2,
#  'You And I - SAINT WKND Remix': 4,
#  'Coastline (feat. Hollow Coves)': 8,
#  "I Can't Help (with Sarcastic Sounds)": 3,
#  'Drew Barrymore': 41,
#  "I Fly (feat. Faouzia) - From 'SCOOB!' The Album": 7,
#  'Higher Ground (feat. John Martin)': 8,
#  'ONLY': 2,
#  'End Of Days': 6,
#  'Lose Somebody': 7,
#  'Own It (feat. Ed Sheeran & Burna Boy) - Joel Corry Remix': 4,
#  'Own It (feat. Ed Sheeran & Burna Boy)': 1,
#  'Blinded By Your Grace, Pt. 2 (feat. MNEK)': 8,
#  'This Time (Never Be Alone Again)': 1,
#  'At Midnight': 2,
#  'Homecoming - Spoken Word with Elena Brower': 1,
#  'Lose You': 4,
#  'Living, Breathing': 23,
#  'LA Money': 1,
#  'Under The Same Sky': 40,
#  'House Arrest': 3,
#  'Zen (with K.Flay & grandson)': 1,
#  'staring at the sea without you next to me': 1,
#  'Shivers - Marsh Remix': 1,
#  'Juanita - Mark Broom Remix': 2,
#  'enemy': 1,
#  'Hold You Tonight (feat. Chris Lane) - Owen Norton Remix': 1,
#  'Garden of Madness 2020 Megamix': 1,
#  'I Still Remember (R3HAB Remix)': 1,
#  'Gasoline (feat. Laura White)': 1,
#  'Good Things Fall Apart (with Jon Bellion) [SLANDER Remix]': 1,
#  'Ghosts (feat. Hana) [Honey & Badger Remix]': 1,
#  'Time - Alan Walker Remix': 1,
#  'Carry On - Möwe Remix': 1,
#  'Details (feat. Boy Matthews) - Joel Corry Remix': 1,
#  'Honolulu - Ninjaneers Remix': 2,
#  'Grace': 2,
#  'Bruises': 1,
#  'Hold Me While You Wait': 1,
#  'Someone You Loved': 8,
#  'Maybe': 4,
#  'Forever': 3,
#  'One': 4,
#  "Don't Get Me Wrong": 1,
#  'Hollywood': 1,
#  'Lost On You': 1,
#  'Fade': 1,
#  'Headspace': 2,
#  'Before You Go': 1,
#  'Leaving My Love Behind': 1,
#  'Let It Roll': 1,
#  'Wind of Change, coming May 11': 1,
#  '1. My Friend Michael': 2,
#  '2. You Call It An Operation, We Call It A Performance': 1,
#  '3. America’s Secret Weapon': 1,
#  '4. The KGB Rock Club': 1,
#  '5. I Follow The Moskva': 1,
#  '6. The Doctor Is In': 3,
#  '7. Rorschach': 1,
#  '8. Hello, Klaus': 1,
#  'Ventura': 6,
#  'Someday': 16,
#  'State Lines': 21,
#  'California': 24,
#  'In the End': 22,
#  'Casimir Pulaski Day': 22,
#  'Honey Hold Me': 23,
#  'What Could Have Been': 22,
#  'Quiver (feat. Lonas)': 8,
#  'Sleepwalking': 31,
#  'Do It For Myself': 5,
#  'Be Right There': 5,
#  'Spiritual (feat. Mr Gabriel)': 5,
#  'All On You': 5,
#  'Le magicien des baguettes (The Baguette Magician)': 1,
#  'Nobody Like You (with Vera Blue)': 2,
#  'The Truth': 4,
#  'Vacuum': 1,
#  '3,000 Miles From Home.': 1,
#  'Eyes Wide Open': 2,
#  'Modern Loneliness - Ritviz Remix': 1,
#  'Blue Fear - Eelke Kleijn Day Mix': 1,
#  'Jonathan Taylor truth serum': 1,
#  "N'Keal Harry calling the bottom": 4,
#  'Heavy On My Heart': 1,
#  'Perfect Instance': 4,
#  'Everything': 7,
#  'Rain On Me (with Ariana Grande)': 8,
#  'Zack Moss Crying Jordan': 2,
#  'The Dreamer': 3,
#  'Old Rain on a New Day': 5,
#  'Adjustments': 7,
#  'Shifts Of Light': 6,
#  'Vague': 14,
#  'De Fléche': 3,
#  'Atlavík': 7,
#  'Waiting like the Storm': 3,
#  'Path to Serenity': 3,
#  'Focus': 15,
#  'Glaciers': 5,
#  'Infinite Sustain': 5,
#  'Understudy': 2,
#  'Closer': 13,
#  'Wild Trails': 3,
#  "I Don't Trust That Bird of Prey": 4,
#  'Selfless': 1,
#  'Solitude': 3,
#  'Day 5: For Carol': 2,
#  'Melvin Gordon looking glass': 4,
#  'Sour Patch Kids': 1,
#  'Fresh Ground (feat. Tim Hecking)': 1,
#  'Work This Time': 2,
#  'Sense': 1,
#  'Slow Jam 1': 1,
#  'Hot Wax': 1,
#  'Fishing For Fishies': 1,
#  "I'm In Your Mind": 1,
#  'Mars For The Rich': 1,
#  'Robot Stop': 1,
#  'Big Fig Wasp': 1,
#  'Gamma Knife': 2,
#  'My Round': 1,
#  'Pity Party - Myles Travitz Remix': 1,
#  '144. 2020 NFL Rookie RB Fantasy Impact & Upside ft. Graham Barfield | Fantasy Football Podcast': 1,
#  '#161 Brian vs. Brian': 1,
#  'Feels Like Forever': 1,
#  'Freedom': 1,
#  'Beautiful': 3,
#  'To Die For': 1,
#  'Broken Glass': 44,
#  'How Would I Know': 1,
#  'Could You Love Me': 1,
#  'Higher Love': 4,
#  "Don't Give Up on Love": 1,
#  'Say You Will': 1,
#  'Follow': 2,
#  'Trade Vetoes Suck + The Diontae Johnson Hype Continues': 1,
#  'How to Attack Your Dynasty Rookie Draft': 1,
#  'Only A Fool (with Pink Sweat$)': 2,
#  'Free (with Drew Love) - Party Favor Remix': 1,
#  'Nothing Really Matters - Nic Fanciulli Remix': 2,
#  'Buenos Aires': 7,
#  'Sour Candy (with BLACKPINK)': 1,
#  'Dance with Me (feat. Thomas Rhett & Young Thug)': 5,
#  'Resistance': 1,
#  'The Bender - Party Pupils Remix': 1,
#  'Hometown (feat. Zac Brown & Danielle Bradbery)': 2,
#  'Heartbreak (feat. Ben Burgess)': 2,
#  'All On Me - Acoustic Version': 1,
#  'Rising Stars': 4,
#  'Intro (feat. Orville Peck)': 2,
#  'So Long (feat. Cam)': 2,
#  'Heartless (feat. Morgan Wallen)': 2,
#  'Lonely (with Jonas Brothers)': 2,
#  'Do Si Do (feat. Blanco Brown)': 1,
#  'On Mine (feat. Noah Cyrus)': 1,
#  'Real Life Stuff (feat. Julia Michaels & Clever)': 1,
#  'Old Town Road (Diplo Remix)': 1,
#  'JustYourSoul - Tchami Remix': 1,
#  'Ultimate Draft Tips + Eye-Popping Insights - Fantasy Football Podcast': 2,
#  '2:38 A.M.': 7,
#  'Empty': 5,
#  'Magical (feat. ZOLLY)': 5,
#  'I Am No Fun': 5,
#  'Cali': 5,
#  'Chances': 5,
#  'Where I Want to Be': 5,
#  "Love Me - Felix Cartal's Chill Mix": 5,
#  'Air': 5,
#  'I feel alive': 4,
#  "Ain't Deep Enough - Bonsai Mammal Chill Mix": 5,
#  'Crystal Castle': 6,
#  'Dreaming - Demo': 4,
#  'Wrong for Me': 5,
#  'Call Me Up': 6,
#  'Fractures': 6,
#  'Sahara': 6,
#  'Get to Know Me': 6,
#  'New Day': 7,
#  'INDIFFERENT (With Gordi)': 5,
#  'Headlights': 7,
#  'Stay': 13,
#  'Shelter': 6,
#  'Sanity': 5,
#  'Who You Are - Mixed': 4,
#  'Hour Glass': 4,
#  "Can't Stay Away from You": 6,
#  'Rockshow': 4,
#  'Colour In Your Heart': 4,
#  'This or That ADP Game + Clenching While Drafting': 1,
#  "Say It Loud - I'm Black And I'm Proud": 1,
#  '16 Shots': 2,
#  'Alright': 1,
#  'Mad (feat. Lil Wayne)': 1,
#  'A Decade Of Watching Black People Die': 2,
#  'Another Irish Drinking Song': 1,
#  'Hair': 1,
#  "Make 'Em Laugh": 1,
#  'Colossus': 1,
#  'Years Of War': 3,
#  "She's My Kind Of Crazy": 1,
#  'Angel Eyes': 1,
#  'Nothing Scares Us (feat. Daniella Mason)': 1,
#  'needy': 1,
#  'Something Like This - Stripped': 1,
#  'Love Me For The Weekend (with Ashe)': 2,
#  'All Night Long': 18,
#  'I Leave Again': 12,
#  'Monday (with Ashe)': 1,
#  'Honeybee': 1,
#  'Falling': 6,
#  'Fantasy State of the Position: Tight End': 3,
#  'Arms Length': 1,
#  '10 Players to Target in the First 10 Rounds of Drafts': 1,
#  'Player Prop Bets To Hammer + The Jets Upgraded O-Line': 1,
#  "How to Pick Your Keepers + DeAndre Hopkins' 2020 Outlook": 2,
#  'My Only Chance': 1,
#  'Make This Right': 1,
#  'Who Am I': 3,
#  'Free My Mind (with DubDogz) - Joy Corporation Remix': 1,
#  'Get in Trouble (So What)': 1,
#  'Fragile': 2,
#  'Coming Over (feat. James Hersey)': 5,
#  'First Time': 3,
#  'Born To Be Yours': 2,
#  'Stargazing': 1,
#  'Electric Feel (Kygo Remix)': 1,
#  'Oasis (feat. Foxes)': 3,
#  'Never Let You Go (feat. John Newman)': 1,
#  'Prelude': 7,
#  'Rewind - Marian Hill Remix': 9,
#  'Through the Night': 10,
#  'Stubborn': 8,
#  'Peace - Acoustic': 9,
#  'Inevitable': 8,
#  'Ur Perfect I Hate It - Lenno Remix': 9,
#  'Lost & In Love (with The Griswolds)': 8,
#  'Why': 8,
#  'Tables Have Turned - Dillistone Remix': 9,
#  'Acetone': 9,
#  'More - Quiet Storm Version': 8,
#  'Out of Town': 8,
#  'Open (feat. Cailin Russo)': 9,
#  'Skin': 8,
#  'Here With U': 8,
#  'Road to Nowhere': 7,
#  'Quantum Physics': 7,
#  'Road Warrior': 8,
#  'Walk on Water': 6,
#  'Face Turns Blue': 41,
#  'Pegao A Ti': 1,
#  "doin' to me": 1,
#  'Colours': 6,
#  'Milkshake - Remix': 13,
#  '6pm': 6,
#  'Overthinking (feat. narou)': 6,
#  'You Should Go': 6,
#  'Long Shot - Mount Pleasant Remix': 7,
#  'Balafono': 6,
#  'It Never Rains': 5,
#  'Euphoria (feat. Travis Scott & Kaash Paige)': 1,
#  'No Idea - Dj Purpberry Chopped and Screwed': 1,
#  'Woke Up Late (feat. Hailee Steinfeld)': 5,
#  'Prefer': 1,
#  'Smart Love': 1,
#  'Relax': 1,
#  'Natural Selection': 1,
#  'Brain': 1,
#  'Fantasy Wildcards + Cook Holdout, Rebuild Tips - Fantasy Football Podcast': 4,
#  'Roses Remix (feat. Future)': 1,
#  'Everything Could Change': 10,
#  'Keep/Trade/Cut + Hype Train, Excuse Wagons - Fantasy Football Podcast': 2,
#  'Tarzan': 1,
#  'Break My Heart - Solardo Remix': 2,
#  'Tomorrow (feat. 433)': 2,
#  'The Last Day': 25,
#  'Heroes': 2,
#  'Warrior': 1,
#  'World On Fire': 1,
#  'Expectations (R3HAB Remix)': 1,
#  'Tommy Lee (feat. Post Malone)': 1,
#  'Cloud 9 (feat. Jeremih)': 1,
#  'All I Need': 1,
#  'Trap - Rompasso Remix': 1,
#  'Clorox Wipe': 1,
#  '20 Breakout Candidates (Ep. 498)': 3,
#  'La Luz': 9,
#  'Young Folks': 4,
#  'While We Are Young': 2,
#  'Dreams': 10,
#  'Spaghetti': 5,
#  'Brothers': 2,
#  'To the Sun and All the Cities in Between': 3,
#  'Those Days Are Now': 2,
#  'Dance of the Dead': 2,
#  'Imagination': 2,
#  'Interlude': 2,
#  'W. 16th St': 2,
#  'La Puerta Roja': 2,
#  'Winter 2011': 2,
#  'Top 15 Bounce-Back Candidates (Ep. 499)': 3,
#  'Hindsight': 5,
#  'The Fool': 5,
#  'go with u': 5,
#  "Can't Let Go (feat. Harry Hudson)": 25,
#  'Pink & Blue (RAC Mix)': 5,
#  'Wake up with You': 5,
#  'Way Up': 6,
#  'Another Light (Cyril Hahn Remix)': 26,
#  'When Am I Gonna Lose You - Medasin Remix': 5,
#  "Don't Wanna Miss You": 27,
#  'Chateau': 5,
#  'Roll Back - TOKiMONSTA Remix': 5,
#  'just listen': 8,
#  'Skip': 4,
#  'Lay Your Head On Me (feat. Marcus Mumford) [Acoustic]': 4,
#  'I Will Wait': 1,
#  'Little Lion Man': 1,
#  'The Cave': 1,
#  'Toronto': 3,
#  'Kids in America (feat. Panama)': 3,
#  'Giver': 2,
#  'Thoughts': 2,
#  'Bummed (feat. Alison Wonderland)': 19,
#  'Trading Places': 23,
#  'Take Your Time': 2,
#  'White Flashes': 2,
#  'State of the Art': 2,
#  'See You in My Dreams': 2,
#  'Running - TELYKast Remix': 2,
#  'New York': 2,
#  'Hide and Seek - Don Diablo Edit': 2,
#  "Thinking 'Bout Love": 2,
#  'A Total Dream': 2,
#  'Not Ok - Frank Walker Remix': 2,
#  'Piano': 22,
#  "I'm Not Alright - Frank Walker Remix": 21,
#  'Good to You': 2,
#  'Stay Forever': 2,
#  'More Than OK': 1,
#  'Family - Frank Walker Remix': 1,
#  'Sleep In - Pryces Remix': 9,
#  'Slack': 16,
#  'Give It to Me': 1,
#  'Surface': 1,
#  'Salt': 1,
#  'Pain Goes Away': 1,
#  'Something': 1,
#  'All in the Value': 1,
#  'Stranger / Lover (Mura Masa Remix)': 1,
#  'Raindrops': 1,
#  'Bloom': 12,
#  'Radar (feat. HONNE)': 8,
#  'Arc-en-ciel': 5,
#  'Swing Swing': 9,
#  'Treat You Better - Cassian Remix': 5,
#  'Throwaway (with Clairo)': 8,
#  'Encore': 5,
#  'Forever Yours': 6,
#  'Places We Don’t Know - ford. Remix': 10,
#  'Thin Floors And Tall Ceilings - ford. Remix': 11,
#  'Wonders of the Unknown': 53,
#  'Lonely': 1,
#  'Lilacs': 6,
#  "it's alright now": 5,
#  'controlla': 6,
#  'tsuyu': 4,
#  'CUPID - Lehvi Remix': 6,
#  'Lazy Sad': 12,
#  'Echoes': 9,
#  'Freak': 10,
#  'Many Words - Goslo Remix': 7,
#  'TROJAN HORSE': 9,
#  'Never': 9,
#  'Me and My Friends - CRi Remix': 7,
#  'Holiday (Off the Edge)': 8,
#  'The Ride': 8,
#  'Flow': 8,
#  'All Your Love': 7,
#  'Razon': 2,
#  'You and I...and New York': 3,
#  'Ambivalence': 6,
#  'Warmth': 8,
#  "Don't Miss It": 7,
#  'Fondness': 11,
#  'Get Lost - Ford. Remix': 5,
#  'Higher': 6,
#  'Sugar': 1,
#  'No Walls In The West': 4,
#  'Standing Rock': 1,
#  'Barcelona': 4,
#  'Paco': 1,
#  'Firefly': 2,
#  '24 Most Overvalued & Undervalued Players (Ep. 502)': 2,
#  'Thousand Faces': 2,
#  'Boom Boom': 1,
#  'Feel Good': 1,
#  'Gunshots': 1,
#  'Together Forever': 3,
#  'A happy memorial': 13,
#  'U Move, I Move (feat. Jhene Aiko)': 1,
#  'Colour Me': 1,
#  'Fresh Roses': 1,
#  'POW POW POW': 2,
#  'My People': 1,
#  'Lose My Cool': 1,
#  'All Night (feat. Ally Brooke) - Chico Rose Extended Remix': 1,
#  'Midnight (feat. Liam Payne) (Jack Wins Remix)': 2,
#  'No Lie - HUGEL Remix': 1,
#  'Sunset Lover': 1,
#  'Take Me Away': 1,
#  'Boom': 1,
#  'Cap (feat. Offset)': 1,
#  'Poppin (feat. Lil Pump & Smokepurpp)': 1,
#  'Millions': 1,
#  'Outlaw': 1,
#  'Two Thousand and Seventeen': 10,
#  'Teenage Birdsong': 9,
#  'Prism': 1,
#  'Utropics': 1,
#  'Borderlands': 1,
#  'Sketch 4': 1,
#  'Amps, Drugs, Harmonium': 1,
#  'Sketch 1': 1,
#  'Bijie Dream': 1,
#  'Sketch 7': 1,
#  'Sea of Pulses': 1,
#  'Hatred of Music I': 1,
#  'Grey Geisha': 1,
#  'Obsidian Counterpoint': 1,
#  'Step away from Konoyo': 1,
#  'Is but a simulated blur': 1,
#  'Keyed out': 1,
#  'In the Air I': 1,
#  'Feel Good Inc.': 2,
#  'Some Kind of Nature (feat. Lou Reed)': 1,
#  'Top 10 Fantasy Football Fades (Ep. 497)': 4,
#  'PPR Mock Draft (Ep. 501)': 1,
#  'Early Breakouts & Busts - Fantasy Football Podcast': 1,
#  'Calvin Ridley milk and honey': 3,
#  'Lush': 8,
#  'Daughter': 7,
#  'Baby': 8,
#  'Locked': 5,
#  'School': 5,
#  '#162 The Least You Could Do': 1,
#  '1998 - Mixed': 3,
#  'No Diggity': 2,
#  'Drop The Game': 3,
#  'What About Us': 2,
#  'This Song Is Not About A Girl': 2,
#  '1998': 1,
#  'Gold': 3,
#  'Talk Is Cheap': 1,
#  'Dive': 2,
#  "Can't Move On": 2,
#  'Dreamcatcher': 29,
#  'KILLING TIME - Acoustic': 2,
#  'Suncats': 2,
#  'Trust': 3,
#  'Running': 11,
#  'No Signal': 2,
#  'Goodbye (feat. Meredith Brackbill & Galvanic)': 3,
#  'Run for Me': 2,
#  'Kyle (I Found You)': 2,
#  'All Mine (feat. Eleven) - Bonjr Remix': 3,
#  'Easy': 2,
#  'Something Familiar': 1,
#  'How Did We Get Here': 1,
#  'Ella': 1,
#  'Cloudburst': 1,
#  'Yasmin you will never hear this': 1,
#  'Have My Back': 1,
#  'Alive': 10,
#  'iinterlude 1': 1,
#  'Up to You': 1,
#  'Read All About It, Pt. III': 1,
#  'Be Free': 2,
#  'Early Sleepers & Values - Fantasy Football Podcast': 4,
#  'Daylight': 10,
#  'Gleams': 1,
#  'Young & Alive': 1,
#  'All Night Long - Y.V.E. 48 Remix': 1,
#  'Wellspring': 1,
#  'Sports Car': 18,
#  'Waiting': 7,
#  "There's Still A Light In The House": 49,
#  "There's Still A Light In The House - Chill Mix": 2,
#  'Pretty Life': 31,
#  'Familiar Faces': 4,
#  'Toi': 9,
#  'Free Problems': 7,
#  'Me 4 Prez': 5,
#  'Oak (feat. Basecamp)': 5,
#  'Make You': 4,
#  '10 Boom or Bust Players + Best Dynasty Draft Bargains (Ep. 504)': 3,
#  'A Phone Call In Amsterdam': 1,
#  'Park Bench': 1,
#  'Harpsichord': 2,
#  'Romantics': 2,
#  'Love Salad': 1,
#  'Insect Near Piha Beach': 1,
#  'Hi Hello': 1,
#  'ISTM': 1,
#  'Something in the Sadness': 1,
#  '1993 Band Practice': 1,
#  'Green': 1,
#  'Bubbles at Overlook 25th March 2019': 1,
#  '4T Recordings': 1,
#  'This Is for You': 1,
#  'Mama Teaches Sanskrit': 1,
#  'Alap': 2,
#  'LA Trance': 2,
#  'Tremper': 2,
#  'Scientists': 2,
#  'Falls 2': 1,
#  'You Are Loved': 1,
#  'SW9 9SL': 1,
#  '10 Midi': 1,
#  'Memories': 2,
#  'Big Love (with EARTHGANG & MNDR)': 9,
#  'Touch - Poolside Remix': 2,
#  'Hollow': 13,
#  'Tonight': 17,
#  'Love Somebody': 2,
#  'Hold On': 26,
#  'Heaven': 4,
#  'Nightcrawler - Illyus & Barrientos Remix': 1,
#  'Sundae': 1,
#  'Medusa': 1,
#  'The Worship': 1,
#  'Looking For Me': 15,
#  'Lose You - Chico Rose Remix': 1,
#  'The Difference - Willaris. K Remix': 1,
#  'Bad News Baby - Acoustic': 1,
#  'Everything Everywhere Matters To Everything': 18,
#  'Matthew Mcconaughey': 1,
#  'Nowhere': 1,
#  'Forget Your Body.': 1,
#  'Trust Nobody': 1,
#  'Pretty Girl - Cheat Codes X CADE Remix': 1,
#  'Future Humans': 2,
#  'Signs and Wonders': 2,
#  "Don't Quit Your Day Job": 3,
#  'Running Around': 3,
#  'The Prawn Song': 1,
#  'The Flood': 3,
#  'Dune': 2,
#  'Open for Business': 2,
#  'Rosyln': 1,
#  'In the Woods': 1,
#  'Chains of Love (On Prisoners of War)': 1,
#  'First Round Draft Advice + 10 Late-Round Must-Haves (Ep. 505)': 2,
#  'The Times Are Tired': 8,
#  '15 Scorching Hot Takes (Ep. 503)': 4,
#  'Chemicals': 13,
#  'Flames (feat. Ruel)': 2,
#  'Hurting (feat. AlunaGeorge)': 1,
#  'Orange Juice': 2,
#  'Chasing Feelings': 1,
#  'Feenicks': 2,
#  'Weightless': 7,
#  'Reset': 1,
#  'Find Love': 1,
#  'Oak': 1,
#  'Find Me': 4,
#  'Fatale': 1,
#  'Madness': 1,
#  'Costello Ave': 1,
#  'Basis': 2,
#  'Let The Light In': 2,
#  'Youuu': 2,
#  "Everybody's Got to Learn Sometime (Tentendo Remix)": 4,
#  'Dip Interlude': 3,
#  'Levvi': 3,
#  'PRBLMS': 1,
#  'ATL Freestyle': 1,
#  'Long Nights': 1,
#  'Float': 1,
#  'Know My Rights (feat. Lil Baby)': 1,
#  'Elephant In The Room': 1,
#  'Outside': 1,
#  '21 Days': 15,
#  'Close': 1,
#  'Sleeping on My Own': 1,
#  'Feel': 1,
#  'The Small Things': 1,
#  'Sudden Changes': 1,
#  'Demand': 1,
#  'Calm Down': 1,
#  'With You - Bronze Whale Remix': 1,
#  'Clouds': 1,
#  'Departure': 1,
#  "Booty-Scootin' Cam Newton + Hold Em' or Fold Em' - Fantasy Football Podcast": 2,
#  'Holy Water': 1,
#  'Left Behind the Gold': 1,
#  '20 Players to Avoid This Year (Ep. 506)': 2,
#  'Sherane a.k.a Master Splinter’s Daughter': 1,
#  'Bitch, Don’t Kill My Vibe': 1,
#  'Backseat Freestyle': 1,
#  'The Art of Peer Pressure': 1,
#  'Money Trees': 1,
#  'Happy?': 1,
#  'Heart': 1,
#  "6's to 9's (feat. Rationale)": 3,
#  'Americans': 1,
#  'Mid-Round RB Rundown + Coaching Changes & Impact (Ep. 507)': 5,
#  'DAWN (feat. Totally Enormous Extinct Dinosaurs) - Edit': 1,
#  'My House': 1,
#  'Horyzon': 2,
#  'Heat Waves': 108,
#  'Ego Death (feat. Kanye West, FKA twigs & Skrillex)': 2,
#  'Oversupply': 1,
#  'Sad About It': 2,
#  'Young Lovers': 2,
#  'Vertigo': 2,
#  'Feels Like': 2,
#  'Buttons': 2,
#  'Ku Ring Gai': 2,
#  'Zorah Come Home': 1,
#  'I Need A Forest Fire': 1,
#  'Catching Eyes': 3,
#  '“Tesla is a 14-year-old LeBron James” — Lemonade goes public. Tesla > Toyota. Walmart’s drive-in movies. ': 1,
#  'Equinox': 7,
#  'Birds': 1,
#  'No Good For You (feat. Jaymes Young)': 1,
#  'Warm Animal - Acoustic': 1,
#  'Gone Again': 1,
#  'Tomorrow': 1,
#  'Lost Like Us': 1,
#  'Stringsnoise': 1,
#  'Home': 7,
#  'Nemesis': 1,
#  '93': 1,
#  'Love That Never': 1,
#  'Still Here': 1,
#  "I Don't Want This Job": 1,
#  'Aquiver': 1,
#  'Next to You': 1,
#  'Overview Effect 1972': 1,
#  'At Sea - Godwolf Remix': 1,
#  'Breathe': 2,
#  'Half-PPR Mock Draft w/ Chris Raybon (Ep. 508)': 3,
#  'Bounce Back Players + Mahomes Extension, Hang Gliding - Fantasy Football Podcast': 1,
#  'WHATS POPPIN': 1,
#  'Dreamer': 12,
#  'Never Come Back - Four Tet Remix': 1,
#  '3AM': 1,
#  'Gong': 1,
#  'Parallel Jalebi': 1,
#  'Our Navigation': 1,
#  'Ba Teaches Yoga': 1,
#  'Kool FM': 1,
#  'Crush': 1,
#  'Buchla': 1,
#  'I Need You To Know': 4,
#  'Lucid Dreams': 4,
#  'i saw your face': 3,
#  'My Rajneesh': 5,
#  "Fallin' In": 3,
#  'Ocean Drive - Purple Disco Machine Remix': 3,
#  "Don't Cry For Me (with Jason Derulo)": 1,
#  'America': 1,
#  'The Ghost Burns (TOKiMONSTA Remix)': 1,
#  'Am I High Rn (feat. blackbear)': 1,
#  'Alane - Don Diablo Remix': 1,
#  'Alane': 1,
#  'Wait Another Day': 1,
#  'Another Night (feat. Matluck) - Acoustic Version': 4,
#  'Be Like That - feat. Swae Lee & Khalid': 1,
#  'Another Night (feat. Matluck)': 25,
#  'Another Night on Mars': 1,
#  'The Beat': 1,
#  'AFC North Breakdown + Double Jump, Buy or Sell - Fantasy Football Podcast': 2,
#  'So Close': 16,
#  'I Wanna Know (feat. Bea Miller)': 4,
#  'Keep You Mine': 2,
#  'I Miss Myself (with HRVY)': 2,
#  'Wanted': 2,
#  'Beautiful People (feat. Khalid) - NOTD Remix': 1,
#  'Been There Done That (feat. Tove Styrke)': 2,
#  'Post Malone (feat. RANI)': 1,
#  "There's Nothing Holdin' Me Back - NOTD Remix": 2,
#  'Romantic - NOTD Remix': 1,
#  'Control - NOTD Remix': 1,
#  '18 Undervalued Studs (Ep. 509)': 3,
#  'Shape of You - NOTD Remix': 1,
#  'Summer Of Love': 1,
#  'Selfish': 2,
#  'Right Now - GATTÜSO Remix': 3,
#  'Missing Home - filous remix': 10,
#  'Big Time - X Games Theme': 3,
#  'Alone': 5,
#  "I Can't Help": 7,
#  '15 Potential Rankings Risers + Fantasy Odd Man Out w/ Sean Koerner (Ep. 510)': 2,
#  'Slow Cycle': 6,
#  'idontwannaknow': 6,
#  'The Kite (Outro)': 16,
#  '20 Deep Sleepers (Ep. 511)': 2,
#  'Monday Blues - Radio Edit': 5,
#  'Atoms - Said the Sky Remix': 4,
#  'Foundations': 4,
#  'Honest': 6,
#  'Honey': 14,
#  'April': 5,
#  'Rainwater': 4,
#  'Found': 4,
#  'Be Slow': 29,
#  'In Another Life': 4,
#  'Move That': 4,
#  'Save Me': 4,
#  'Most People': 4,
#  'Hold Me Tonight': 3,
#  'No Roof Access': 20,
#  'Farenag': 3,
#  "Mind's Eye": 3,
#  'Flamingo': 31,
#  'Ocean Eyes - Astronomyy Remix': 1,
#  'Dust': 3,
#  'CEH No Matter What - Ft. Graham Barfield & Scott Barrett ': 1,
#  'Raheem Mostert trust fall': 1,
#  'Cool For A Second': 4,
#  'Life On Mars': 4,
#  'Cherie': 3,
#  'Alpine': 3,
#  'Imperfection': 4,
#  'Pressure (with SG Lewis)': 15,
#  'What I Know': 3,
#  'This Place': 12,
#  'Hypnotized': 1,
#  "Things I'd Do for U": 1,
#  "Don't Need U": 1,
#  "Everythin' on My Mind": 1,
#  'Rest in Paradise': 1,
#  'Long Shadow, Short Temper': 1,
#  'Woof': 15,
#  'AFC West Breakdown + Henry Gets Paid - Fantasy Football Podcast': 2,
#  "What's Love Got to Do with It": 1,
#  'Aftertaste (Mixed)': 2,
#  'Hold You Tonight (with Chris Lane) - Acoustic': 1,
#  'Desire - Single Edit': 1,
#  'Kill Me Slow': 19,
#  'Jam': 1,
#  '5 Seconds Before Sunrise': 23,
#  'Funny': 124,
#  'Hate Me': 1,
#  'Imagine': 13,
#  'Thinking About You (with Winona Oak)': 1,
#  'Crazy': 3,
#  'Get Your Wish - Anamanaguchi Remix': 1,
#  'The Middle': 4,
#  'Get Low (with Liam Payne)': 1,
#  'Happy Now': 3,
#  'Clarity': 2,
#  'Delta': 1,
#  'Let Her Go': 5,
#  "Like I'm Gonna Lose You": 2,
#  'You Are My Sunshine': 2,
#  'Rather Be': 3,
#  "Ain't Nobody (Loves Me Better) - Acoustic": 2,
#  "Ain't Nobody (Loves Me Better) (feat. Jasmine Thompson)": 1,
#  'Willow': 2,
#  'Mad World': 2,
#  'I Try': 2,
#  'Old Friends': 1,
#  'Everything Has Changed': 1,
#  '7 Years': 2,
#  'Almost Lover': 1,
#  'Will Follow You Into the Dark': 1,
#  'Adore': 2,
#  'Holding You Close': 1,
#  'I Want You To Know': 1,
#  'Beautiful Now': 1,
#  'Blinding Lights': 33,
#  'Muirfield': 1,
#  '30000': 1,
#  'Yellow': 1,
#  'Somebody': 1,
#  'Lifetime': 1,
#  'Reality': 2,
#  'Pinkman - Instrumental mix': 1,
#  'Aurora': 1,
#  'Lovelike': 1,
#  'sunday': 6,
#  'ONDAWAY': 1,
#  'Something More': 1,
#  "Don't Mind That We're Lonely": 1,
#  'Keep It Simple (feat. Wilder Woods) - Rayet Remix': 1,
#  'Move Me': 9,
#  'Do It Better': 1,
#  'Open End Resource - Leaving Laurel Remix': 1,
#  'Up in Flames': 1,
#  'Losing Myself': 1,
#  'You Got Me': 1,
#  'Friday - OKO Remix': 1,
#  'Right Way': 1,
#  'Life Is So Beautiful': 1,
#  'Breakfast in Bed': 1,
#  '21 Tips for Draft Domination (Ep. 513)': 4,
#  'Best Kept Secrets, Last Place Punishments + The NFL & Coronavirus - Fantasy Football Podcast': 4,
#  'Lucy In The Sky With Diamonds - Remastered 2009': 1,
#  'Getting Better - Remastered 2009': 1,
#  'Fixing A Hole - Remastered 2009': 1,
#  "She's Leaving Home - Remastered 2009": 1,
#  'Being For The Benefit Of Mr. Kite! - Remastered 2009': 1,
#  'Within You Without You - Remastered 2009': 1,
#  "When I'm Sixty Four - Remastered 2009": 1,
#  'Lovely Rita - Remastered 2009': 1,
#  'Good Morning Good Morning - Remastered 2009': 1,
#  "Sgt. Pepper's Lonely Hearts Club Band - Reprise / Remastered 2009": 1,
#  'A Day In The Life - Remastered 2009': 1,
#  "Sgt. Pepper's Lonely Hearts Club Band - Remastered 2009": 1,
#  'With A Little Help From My Friends - Remastered 2009': 1,
#  'Steady 1234 (feat. Jasmine Thompson & Skizzy Mars)': 1,
#  'Kickback': 4,
#  'Drop Your Guard': 1,
#  'Royals': 1,
#  'Wrecking Ball': 1,
#  'Demons': 1,
#  'A Thousand Years': 1,
#  'Not About Angels': 1,
#  'Breathe Me': 1,
#  'Say Something': 1,
#  'All of Me': 1,
#  'I See Fire': 2,
#  'Everybody Hurts': 1,
#  'La la La': 1,
#  'PPR Mock Draft w/ Adam Rank (Ep. 514)': 1,
#  'In Your Eyes': 1,
#  'All My Friends': 45,
#  'iSpy (feat. Lil Yachty)': 2,
#  'Hurting on Purpose (feat. K.Flay)': 2,
#  'KEEP MOVING': 2,
#  'Embers': 16,
#  'Savage (feat. Flux Pavilion & MAX)': 11,
#  ...}

# %% [markdown]
# ## Write Functions Using spotipy to Retrieve Track Information
# [spotipy](https://spotipy.readthedocs.io/en/2.18.0/) is a handy python package that makes it straightforward to access the [Spotify API](https://developer.spotify.com/documentation/web-api/), so we'll be using it to gather additional information on the tracks in our listening history.  Spotify only gives us the Track Name and Artist Name in the listening history, and not their actual internal unique iD for the track that we can use to search for all of it's attributes. Therefore through spotipy and the Spotify API the first function we'll write retrieves the Spotify iD of each track by searching for the trackName and artistName. We'll also get the track type (song vs. podcast) while we're there, so that we can analyze our song vs. podcast listening habits.

# %%
def search_track_name(track_name: str, artist_name: str) -> str:
    
    '''This function takes the track name and artist name as parameters and combines them into a string and
       searches Spotify first for tracks, and then if there are no results, searches for podcasts that match 
       the searched string. If there are no results for either it returns none. If a track or a podcast is 
       found it returns the track id and the track type.
       
       In the sp.search function type refers to the type of Spotify item to search (e.g. track, episode, artist,
       album).  ''';
    
    search_track = sp.search(q=track_name+' '+artist_name, offset=0, type='track', market='US')
    if len(search_track['tracks']['items']) == 0:
        search_episode = sp.search(q=track_name+' '+artist_name, offset=0, type='episode',market = 'US')
        if search_episode['episodes']['items'] == [None]:
            return None, None
        else:
            try:
                track_id = search_episode['episodes']['items'][0]['id']
                track_type = search_episode['episodes']['items'][0]['type']
                return track_id, track_type
            except:
                print('search failed', track_name)
                return None, None
    else:
        track_id = search_track['tracks']['items'][0]['id']
        track_type = search_track['tracks']['items'][0]['type']
        return track_id, track_type

# %% [markdown]
# ## Function to Return Audio Features from Track iD
# Audio features are attributes assigned to every song by Spotify. There are 18 items included in the Spotify AudioFeaturesObject for each song and they are described by Spotify as follows. These descriptions can be found from Spotify [here](https://developer.spotify.com/documentation/web-api/reference/#object-audiofeaturesobject): <br>
#
# <b>acousticness</b> - "A confidence measure from 0.0 to 1.0 of whether the track is acoustic. 1.0 represents high confidence the track is acoustic."<br>
# analysis_url - "An HTTP URL to access the full audio analysis of this track. An access token is required to access this data." <br>
# <b>danceability</b> - "Danceability describes how suitable a track is for dancing based on a combination of musical elements including tempo, rhythm stability, beat strength, and overall regularity. A value of 0.0 is least danceable and 1.0 is most danceable." <br>
# <b>duration_ms</b> - "The duration of the track in milliseconds." <br>
# <b>energy</b> - "Energy is a measure from 0.0 to 1.0 and represents a perceptual measure of intensity and activity. Typically, energetic tracks feel fast, loud, and noisy. For example, death metal has high energy, while a Bach prelude scores low on the scale. Perceptual features contributing to this attribute include dynamic range, perceived loudness, timbre, onset rate, and general entropy." <br>
# <b>id</b> - "The Spotify ID for the track." <br>
# instrumentalness - "Predicts whether a track contains no vocals. “Ooh” and “aah” sounds are treated as instrumental in this context. Rap or spoken word tracks are clearly “vocal”. The closer the instrumentalness value is to 1.0, the greater likelihood the track contains no vocal content. Values above 0.5 are intended to represent instrumental tracks, but confidence is higher as the value approaches 1.0." <br>
# <b>key</b> - "The key the track is in. Integers map to pitches using standard Pitch Class notation . E.g. 0 = C, 1 = C♯/D♭, 2 = D, and so on." <br>
# <b>liveness</b> - "Detects the presence of an audience in the recording. Higher liveness values represent an increased probability that the track was performed live. A value above 0.8 provides strong likelihood that the track is live." <br>
# <b>loudness</b> - "The overall loudness of a track in decibels (dB). Loudness values are averaged across the entire track and are useful for comparing relative loudness of tracks. Loudness is the quality of a sound that is the primary psychological correlate of physical strength (amplitude). Values typical range between -60 and 0 db." <br>
# <b>mode</b> - "Mode indicates the modality (major or minor) of a track, the type of scale from which its melodic content is derived. Major is represented by 1 and minor is 0." <br>
# <b>speechiness</b> - "Speechiness detects the presence of spoken words in a track. The more exclusively speech-like the recording (e.g. talk show, audio book, poetry), the closer to 1.0 the attribute value. Values above 0.66 describe tracks that are probably made entirely of spoken words. Values between 0.33 and 0.66 describe tracks that may contain both music and speech, either in sections or layered, including such cases as rap music. Values below 0.33 most likely represent music and other non-speech-like tracks." <br>
# <b>tempo</b> - "The overall estimated tempo of a track in beats per minute (BPM). In musical terminology, tempo is the speed or pace of a given piece and derives directly from the average beat duration." <br>
# <b>time_signature</b> - "An estimated overall time signature of a track. The time signature (meter) is a notational convention to specify how many beats are in each bar (or measure)." <br>
# <b>track_href</b> - "A link to the Web API endpoint providing full details of the track." <br>
# <b>type</b> - "The object type: “audio_features""<br>
# <b>uri</b> - "The Spotify URI for the track."<br>
# <b>valence</b> - "A measure from 0.0 to 1.0 describing the musical positiveness conveyed by a track. Tracks with high valence sound more positive (e.g. happy, cheerful, euphoric), while tracks with low valence sound more negative (e.g. sad, depressed, angry)."

# %%
   '''Note that only songs have audio features, podcasts do not. If we search an episode iD in this 
      function it will return none''';
    
def get_features(track_id: str) -> dict:
    if track_id == None:
        return None
    try:
        features = sp.audio_features([track_id])
        return features[0]
    except:
        return None

# %% [markdown]
# ## Function to Return Track Popularity from Track iD
# Note that podcast episodes do not have popularity.

# %%
def track_popularity(track_id: str):
    if track_id == None:
        return None
    try:
        track_info = sp.track(track_id)
        track_pop = track_info['popularity']
        return track_pop
    except:
        return None

# %% [markdown]
# ## Function to Return Artist Genres, id, Popularity, and Name from Track iD
# We'll now retrieve the artist info for the primary artist on the track. it is worth noting that the genres returned here are all of the genres associated with the artist in their Spotify profile, not specifically associated with the track we are search. Also note that podcast artists will not have this information.

# %%
def get_artist_info(track_id: str):
    if track_id == None:
        return None, None, None, None
    try:
        track_info = sp.track(track_id)
        artist_id = track_info['artists'][0]['id']
        artist_info = sp.artist(artist_id)
        artist_genres = artist_info['genres']
        artist_popularity = artist_info['popularity']
        artist_name = artist_info['name']
        return artist_id, artist_genres, artist_popularity, artist_name
    except: 
        return None, None, None, None

# %% [markdown]
# ## Loop Over Dictionary of Unique trackName:artistName Pairs to retrieve all Track and Artist Info
# Now it's time to put it all together and retrieve all this information for each track. We'll be searching for each track, storing all found information in a dictionary of dictionaries, and dealing with podcast episodes and tracks that search could not find at all. Step by step our process will be: <br><br>
#     1. Set up an optional counter to be able to check in on the loop's progress.<br>
#     2. Loop through the trackName:artistName dictionary of unique songs we created above. For each pair we will each step listed below <br>
#     3. Connect to the API.<br>
#     4. Retrieve the track ID and type and store them as variables with the first function we wrote `search_track_name()`
#     5. Retrieve and store the track popularity using the `track_popularity()` function and the track ID. <br>
#     6. Retrieve and store the artist info with the `get_artist_info()` function. <br>
#     7. If the track type is episide or None we have enough information to know that we shouldn't waste time running the rest of the functions, so we will will out the fields in the final dictionary with the information we know. <br>
#     8. If the track type is track we need to run the popularity, artist info, and features functions. We put those in an if statement with the type, run the functions and fill the information into the dictionary for the track. <br>

# %%
#Create dictionary that will house trackName:{trackFeature} key value pairs.
all_features = {}
#I included a list and counter to keep track of the loops progress as it takes a fair bit of time. 
counter_list = [50, 100,200,300,400,500,600,700,800,900,1000,1100,1200,1300,1400,1500,1600,1700,1800,1900,
                2000,2100,2200,2300,2400,2500,2600,2700,2800,2900,3000,3100,3200,3300,3400]
counter = 0
for track, artist in track_artist_dict.items():
    sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager)
    #Search for track and retrieve track id and track type (if search suceeeds)
    track_id, track_type = search_track_name(track, artist)
    #If the track_type is episode, create the track feature dictionary as no other functions work for podcasts
    if track_type == 'episode':
        additional_features = {'artist_name': artist, 'artist_genres': 'podcast', 'artist_popularity':None,
                               'track_popularity':None}
        all_features[track] = {'danceability': None, 'energy': None, 'key': None, 'loudness': None, 
                               'mode': None, 'speechiness': None, 'acousticness': None, 'instrumentalness': None, 
                               'liveness': None, 'valence': None, 'tempo': None, 'type': 'episode', 'id': track_id, 
                               'uri': None, 'track_href': None, 'analysis_url': None, 'duration_ms': 0, 
                               'time_signature': None}
        all_features[track].update(additional_features)
        
    #If the search did not find the track add an empty dictionary 
    elif track_type == None:
        unknown_features = {'danceability': None, 'energy': None, 'key': None, 'loudness': None, 'mode': None, 
                            'speechiness': None, 'acousticness': None, 'instrumentalness': None, 'liveness': None, 
                            'valence': None, 'tempo': None, 'type': None, 'id': None, 'uri': None, 
                            'track_href': None, 'analysis_url': None, 'duration_ms': 0, 'time_signature': None, 
                            'artist_name': artist, 'artist_genres': None, 'artist_popularity':None, 
                            'track_popularity':None}
        
    # If the track_type is track retrieve the track popularity, audio features, and artist info. Then fill out the
    # dictionary entry for the track with this information
    elif track_type == 'track':
        track_pop = track_popularity(track_id)
        artist_id, artist_genres, artist_popularity, artist_name = get_artist_info(track_id)
        additional_features = {'artist_name': artist, 'artist_genres': artist_genres, 'artist_popularity':artist_popularity, 'track_popularity':track_pop, 'type':'track'}
        features = get_features(track_id)
        if features:
            all_features[track] = features
            all_features[track].update(additional_features)
        else:  #In case there is a song with an id and without audio features. 
            all_features[track] = {'danceability': None, 'energy': None, 'key': None, 'loudness': None, 'mode': None, 'speechiness': None, 'acousticness': None, 'instrumentalness': None, 'liveness': None, 'valence': None, 'tempo': None, 'type': 'Track', 'id': None, 'uri': None, 'track_href': None, 'analysis_url': None, 'duration_ms': 0, 'time_signature': None, 'artist_name': artist, 'artist_genres': None, 'artist_popularity':None, 'track_popularity':None}
            all_features[track].update(additional_features)

    #Optional progress tracking code
    counter += 1
    if counter in counter_list:
        print(counter,' done')
        print('length all features ',len(all_features))
        
            
print('IDs and Features retrieved')
# Out:
# search failed FISA Follies & Trump’s Taxes (with Steve Vladeck)
# 50  done
# length all features  49
# search failed Proud (feat. Daecolm) [Dogma Remix]
# 100  done
# length all features  98
# search failed Ghosts (feat. Hana) [Honey & Badger Remix]
# 200  done
# length all features  197
# 300  done
# length all features  297
# search failed Trade Vetoes Suck + The Diontae Johnson Hype Continues
# search failed How to Attack Your Dynasty Rookie Draft
# search failed Colossus
# search failed Fantasy State of the Position: Tight End
# search failed 10 Players to Target in the First 10 Rounds of Drafts
# search failed Player Prop Bets To Hammer + The Jets Upgraded O-Line
# search failed How to Pick Your Keepers + DeAndre Hopkins' 2020 Outlook
# 400  done
# length all features  390
# search failed Overthinking (feat. narou)
# search failed Break My Heart - Solardo Remix
# search failed Kids in America (feat. Panama)
# 500  done
# length all features  487
# search failed Lonely
# 600  done
# length all features  586

# %% [markdown]
# ## Finalize Formatting and Save Necessary .csv files
# Our previous loop returned a dictionary with trackNames as keys and dictionaries with all the track inforation as values. To convert to a dataframe and save as a csv we'll make this into a list of dictionary. Each dictionary will have the name of the track and then all of the track information we just retrieved.

# %%
with_features = []
for track_name, features in all_features.items():
    #unpack the dictionary that was the value in `all_features` and concatinate it with the name of the track. 
    with_features.append({'name': track_name, **features})

# %%
track_names = []
for key in track_count_dict:
    track_names.append(key)
track_plays = []
for key in track_count_dict:
    track_plays.append(track_count_dict[key])
play_count_df = {'trackName':track_names,
                         'trackPlays':track_plays}

# %%
df = pd.DataFrame(with_features)
df.to_csv('listening_history_unique_songs.csv')

# %%
df = pd.DataFrame(play_count_df)
df.to_csv('track_play_counts.csv')
